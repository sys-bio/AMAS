# %%
# Additional analysis from agora2_checking.ipynb
 
import collections
from collections import Counter

import compress_pickle
import copy
import editdistance
import itertools
import libsbml
import numpy as np
import operator
import os
import pickle
import pandas as pd
import random
import sys
import time
import matplotlib.pyplot as plt
# %matplotlib inline  

BIOMD_12 = 'BIOMD0000000012.xml'
BASE_DIR = '/Users/woosubshin/Desktop/AutomateAnnotation/'
DATA_DIR = os.path.join(BASE_DIR, "DATA")
ALGO_DIR = os.path.join(DATA_DIR, "algo")
CHEBI_DIR = os.path.join(DATA_DIR, "chebi")
FIGURE_DIR = '/Users/woosubshin/Desktop/AutomateAnnotation/AMAS_suppl/figure_files'
RHEA_DIR = os.path.join(DATA_DIR, "rhea")
BIOMODEL_DIR = os.path.join(DATA_DIR, "biomodels/curated_biomodels_31mar2021")
BIGG_DIR = '/Users/woosubshin/Desktop/AutomateAnnotation/DATA/bigg'
ecoli_fpath = os.path.join(BIGG_DIR, "e_coli_core.xml")

PROJ_DIR = os.path.join(os.getcwd(), os.pardir)
AMAS_DIR = os.path.join(PROJ_DIR, "AMAS")
sys.path.append(PROJ_DIR)

SUPPL_DIR = os.path.join(PROJ_DIR, os.pardir, "AMAS_suppl")
ACCURACY_DIR = os.path.join(SUPPL_DIR, "data_for_credibility")

# address changed - as of May 12, 2023. 
MANU_FIGURE_DIR = '/Users/woosubshin/Desktop/AutomateAnnotation/writeup/AMAS/Manu_figures_new'
SUPPL_FIGURE_DIR = '/Users/woosubshin/Desktop/AutomateAnnotation/writeup/AMAS/Supple_figures_new'

PRES_DIR = '/Users/woosubshin/Desktop/AutomateAnnotation/presentation/sauro_lab/sauro_lab_2023/jun82023'

from AMAS import species_annotation as sa
from AMAS import reaction_annotation as ra
from AMAS import recommender
from AMAS import constants as cn
from AMAS import iterator as it
from AMAS import tools

biggs = [val for val in os.listdir(BIGG_DIR) if val[-4:]=='.xml']
print("Number of BiGG models to be analyzed: %d" % len(biggs))

spec_ml_df = pd.read_csv(os.path.join(ACCURACY_DIR, 'biomd_individual_species_accuracy.csv'))
biomds_spec = np.unique(spec_ml_df['model'])
print("Number of BioModels to be analyzed for SPECIES: %d" % len(biomds_spec))

reac_ml_df = pd.read_csv(os.path.join(ACCURACY_DIR, 'biomd_individual_reactions_accuracy.csv'))
biomds_reac = np.unique(reac_ml_df['model'])
print("Number of BioModels to be analyzed for REACTIONS: %d" % len(biomds_reac))


SAVE_FPATH = '/Volumes/MGTEC/Agora2'
# Out:
# Number of BiGG models to be analyzed: 108
# Number of BioModels to be analyzed for SPECIES: 306
# Number of BioModels to be analyzed for REACTIONS: 131

# %%
agoras = [val for val in os.listdir(SAVE_FPATH) if val[-3:]=='xml']
print(len(agoras))
biggs = [val for val in os.listdir(BIGG_DIR) if val[-3:]=='xml']
print(len(biggs))
# Out:
# 7302
# 108

# %%
models_not_working = []
agora_all_species_ll = []

for idx, one_a in enumerate(agoras):
  if idx % 1000 == 0:
    print("We're at", idx)
  one_fpath = os.path.join(SAVE_FPATH, one_a)
  try: 
    recom = recommender.Recommender(libsbml_fpath=one_fpath)
  except:
    models_not_working.append(one_a)
    continue
  model = recom.sbml_document.getModel()
  agora_all_species_ll.append([recom.species.getNameToUse(val.getId()) \
                               for val in model.getListOfSpecies()])
agora_all_species = list(set(itertools.chain(*agora_all_species_ll)))

# total number of unique species IDs used throughout agora 2
len(agora_all_species)
# Out:
# We're at 0
# We're at 1000
# We're at 2000
# We're at 3000
# We're at 4000
# We're at 5000
# We're at 6000
# We're at 7000
# 3266

# %%
######
###### ver. 2???
models_not_working = []
agora_all_species_ll = []
agors_all_reactions_ll = []

for idx, one_a in enumerate(agoras):
  if idx % 1000 == 0:
    print("We're at", idx)
  one_fpath = os.path.join(SAVE_FPATH, one_a)
  try: 
    recom = recommender.Recommender(libsbml_fpath=one_fpath)
  except:
    models_not_working.append(one_a)
    continue
  model = recom.sbml_document.getModel()
  agora_all_species_ll.append([recom.species.getNameToUse(val.getId()) \
                               for val in model.getListOfSpecies()])
  agora_all_reactions_ll.append([val.getId() for val in model.getListOfReactions()])
agora_all_species = list(set(itertools.chain(*agora_all_species_ll)))
agora_all_reactions = list(set(itertools.chain(*agora_all_reactions_ll)))

# total number of unique species IDs used throughout agora 2
print(len(agora_all_species))
print(len(agora_all_reactions))

########
########
# Out:
# We're at 0
# We're at 1000
# We're at 2000
# We're at 3000
# We're at 4000
# We're at 5000
# We're at 6000
# We're at 7000
# 3266
# 6883

# %%
def PrintTotAveNum(ll):
  """
  Print the total and
  model-level average 
  number of models in the repository
  
  Parameters
  ----------
  ll: list-list
      e.g., [[100, 202, 303], [...]]
      
  Returns
  -------
  Null
  """
  totalnum = np.sum([len(val) for val in ll])
  avenum = totalnum / len(ll)
  print("Total number: %d, Average per model: %.0f" % (totalnum, avenum))

# %%
PrintTotAveNum(agora_all_species_ll)

PrintTotAveNum(agors_all_reactions_ll)

PrintTotAveNum(bigg_all_species_ll)

PrintTotAveNum(bigg_all_reactions_ll)
# Out:
# Total number: 6826775, Average per model: 1229
# Total number: 7505652, Average per model: 1351
# Total number: 180802, Average per model: 1674
# Total number: 251424, Average per model: 2328

# %%
totalnum_agora_species = np.sum([len(val) for val in agora_all_species_ll])
totalnum_agora_reactions = np.sum([len(val) for val in agors_all_reactions_ll])
totalnum_bigg_species = np.sum([len(val) for val in bigg_all_species_ll])
totalnum_bigg_reactions = np.sum([len(val) for val in bigg_all_reactions_ll])

print(totalnum_agora_species)
print(totalnum_agora_reactions)
print(totalnum_bigg_species)
print(totalnum_bigg_reactions)
# Out:
# 5556

# %%
# summary of biggs

bigg_all_species_ll = []
bigg_all_reactions_ll = []
for idx, one_bigg in enumerate(biggs):
  if idx % 20 == 0:
    print("We're at", idx)
  one_fpath = os.path.join(BIGG_DIR, one_bigg)
  recom = recommender.Recommender(libsbml_fpath=one_fpath)
  model = recom.sbml_document.getModel()
  bigg_all_species_ll.append([recom.species.getNameToUse(val.getId()) \
                               for val in model.getListOfSpecies()])
  bigg_all_reactions_ll.append([val.getId() \
                               for val in model.getListOfReactions()])
bigg_all_species = list(set(itertools.chain(*bigg_all_species_ll)))
bigg_all_reactions = list(set(itertools.chain(*bigg_all_reactions_ll)))


# total number of unique species IDs used throughout agora 2
print(len(bigg_all_species))
print(len(bigg_all_reactions))
# Out:
# We're at 0
# We're at 20
# We're at 40
# We're at 60
# We're at 80
# We're at 100
# 8813
# 28548

# %%
# From AGORA2; detecting CHEBI:1 with spurious species
one_a = agoras[0]
one_a = 'Yersinia_kristensenii_Y231.xml'
one_fpath = os.path.join(SAVE_FPATH, one_a)
recom = recommender.Recommender(libsbml_fpath=one_fpath)
value_trips = []
comb_specs = [val.getId() for val in model.getListOfSpecies()]
for one_k in recom.species.exist_annotation.keys():
  model = recom.sbml_document.getModel() 
  value_trips.append((one_k,
                      recom.species.getNameToUse(one_k),
                      recom.species.exist_annotation[one_k]))
rem_specs = [val for val in comb_specs if val not in recom.species.exist_annotation.keys()]
model.getNumSpecies()
# Out:
# 1375

# %%
print(model.getSpecies(rem_specs[5]).name)
# Out:
# 10-methyl-dodecanoyl-ACP

# %%
recom.recommendSpecies('M_Largn__91__c__93__')
# Out:
#                              file     type                    id display name  \
# 0  Yersinia_kristensenii_Y231.xml  species  M_Largn__91__c__93__  L-Arogenate
# 1  Yersinia_kristensenii_Y231.xml  species  M_Largn__91__c__93__  L-Arogenate
# 2  Yersinia_kristensenii_Y231.xml  species  M_Largn__91__c__93__  L-Arogenate
#
#                 meta id   annotation   annotation label  match score  \
# 0  M_Largn__91__c__93__  CHEBI:17530    L-arogenic acid        1.000
# 1  M_Largn__91__c__93__  CHEBI:58180    L-arogenate(1-)        1.000
# 2  M_Largn__91__c__93__  CHEBI:18357  (R)-noradrenaline        0.889
#
#    existing UPDATE ANNOTATION
# 0         0            ignore
# 1         0            ignore
# 2         1              keep

# %%
# first model
value_trips = []
for one_k in recom.species.exist_annotation.keys():
  model = recom.sbml_document.getModel() 
  value_trips.append((one_k,
                      recom.species.getNameToUse(one_k),
                      recom.species.exist_annotation[one_k]))

# %%
recom.recommendSpecies('M_10fthf__91__c__93__')
# Out:
#                                    file     type                     id  \
# 0  Abiotrophia_defectiva_ATCC_49176.xml  species  M_10fthf__91__c__93__
#
#                 display name                meta id   annotation  \
# 0  10-Formyltetrahydrofolate  M_10fthf__91__c__93__  CHEBI:15637
#
#                 annotation label  match score  existing UPDATE ANNOTATION
# 0  10-formyltetrahydrofolic acid          1.0         0            ignore

# %%
random.sample(working_agoras, 4)
# Out:
# ['Lactobacillus_animalis_ERR2221280.xml',
#  'Lactobacillus_casei_ERR2221291.xml',
#  'Intestinibacter_nov_ERR2221096.xml',
#  'Acinetobacter_baumannii_MDR_ZJ06.xml']

# %%
# find all elements with 10-Formyltetrahydrofolate as a display name
formyl_tups = []
FORMYL = '10-Formyltetrahydrofolate'
FORMYL_ID = 'M_10fthf__91__c__93__'
IDS = ['M_10fthf__91__c__93__',
       'M_12ppd_S__91__c__93__',
       'M_13dpg__91__c__93__']


comb_tups = {val:[] for val in IDS}
working_agoras = [val for val in agoras if val not in models_not_working]

for idx, one_a in enumerate(working_agoras):
  if idx % 1000 == 0:
    print("We're at", idx)
  one_fpath = os.path.join(SAVE_FPATH, one_a)
  recom = recommender.Recommender(libsbml_fpath=one_fpath)
  model = recom.sbml_document.getModel()
  specs = [val.getId() for val in model.getListOfSpecies()]
  for ONE_ID in [FORMYL_ID]:
    if ONE_ID in specs:
      filt_specs = [val for val in specs if val==ONE_ID]
      for one_s in filt_specs:
        if ONE_ID in recom.species.exist_annotation.keys():
          annotation = recom.species.exist_annotation[ONE_ID]
        else:
          annotation = 'not existing'
        comb_tups[ONE_ID].append((one_a,
                                  recom.species.getNameToUse(ONE_ID),
                                  annotation[0]
                                 ))
# Out:
# We're at 0
# We're at 1000
# We're at 2000
# KeyboardInterrupt

# %%
# to calculate cohen's kappa
ag1 = working_agoras[0]
ag2 = working_agoras[1]
ag3 = working_agoras[3]

one_fpath1 = os.path.join(SAVE_FPATH, ag1)
recom1 = recommender.Recommender(libsbml_fpath=one_fpath1)
agm1 = recom1.sbml_document.getModel()

one_fpath2 = os.path.join(SAVE_FPATH, ag2)
recom2 = recommender.Recommender(libsbml_fpath=one_fpath2)
agm2 = recom2.sbml_document.getModel()

one_fpath3 = os.path.join(SAVE_FPATH, ag3)
recom3 = recommender.Recommender(libsbml_fpath=one_fpath3)
agm3 = recom3.sbml_document.getModel()




# tups = []
# for one_a in [ag1, ag2]:
#   one_fpath = os.path.join(SAVE_FPATH, one_a)
#   recom = recommender.Recommender(libsbml_fpath=one_fpath)
#   model = recom.sbml_document.getModel()
#   model_tups = []
#   for one_s in model.getListOfSpecies():
#     if one_s.getId() in recom.species.exist_annotation.keys():
#       model_tups.append((one_s.getId(),
#                         recom.species.getNameToUse(one_s.getId()),
#                         recom.species.exist_annotation[one_s.getId()][0]))
#     # else:
#     #   model_tups.append((one_s.getId(),
#     #                     recom.species.getNameToUse(one_s.getId()),
#     #                     'None'))
#   tups.append(model_tups)

# %%
one_a = 'Yersinia_kristensenii_Y231.xml'
one_fpath = os.path.join(SAVE_FPATH, one_a)
recom = recommender.Recommender(libsbml_fpath=one_fpath)
model = recom.sbml_document.getModel()
recom.species.exist_annotation['M_Largn__91__c__93__']
# Out:
# ['CHEBI:18357']

# %%
agm2.getNumSpecies()
# Out:
# 952

# %%
com_ids = list(set(recom2.species.exist_annotation.keys()).intersection(recom3.species.exist_annotation.keys()))
print(len(com_ids))
# Out:
# 485

# %%
res = []
for one_s in com_ids:
  if recom2.species.exist_annotation[one_s] == recom3.species.exist_annotation[one_s]:
    res.append(True)
  else:
    res.append(False)
np.mean(res)
# Out:
# 1.0

# %%
ag2
# Out:
# 'Acaricomes_phytoseiuli_DSM_14247.xml'

# %%
# # subjects
# com_ids = list(set(recom1.species.exist_annotation.keys()).intersection(recom2.species.exist_annotation.keys()))
# N = len(com_ids)
# # n: number of raters
# n = 2
# Nn = N*n

# # collect unique chebi terms
# chebis1 = set(itertools.chain(*[val[1] for val in list(recom1.species.exist_annotation.items()) \
#                                if val[0] in com_ids]))
# chebis2 = set(itertools.chain(*[val[1] for val in list(recom2.species.exist_annotation.items()) \
#                                if val[0] in com_ids]))
# chebis = list(chebis1.union(chebis2))
# k = len(chebis)

# # create df
# df = pd.DataFrame(np.zeros((len(com_ids), len(chebis))))
# df.index=com_ids
# df.columns=chebis
# print(df.shape)
# for one_id in df.index:
#   df.loc[one_id, recom1.species.exist_annotation[one_id][0]] += 1
#   df.loc[one_id, recom2.species.exist_annotation[one_id][0]] += 1
    
# # p_j
# pjs = df.sum(0) / Nn

# # P_i
# pis = [(np.sum([val**2 for val in df.loc[one_i,:]])-2)/2 for one_i in df.index]

# pbar = np.sum(pis)/N
# pebar = np.sum([val**2 for val in pjs])

# kappa = (pbar-pebar)/(1-pebar)
# print(kappa)

# %%
one_i = df.index[0]
len([(np.sum([val**2 for val in df.loc[one_i,:]])-2)/2 for one_i in df.index])
# Out:
# 516

# %%
def getFleiss(one_recom, two_recom):
  """
  Get Fleiss' kappa
  using two recom classes
  
  Parameters
  ----------
  one_recom: AMAS.Recommender
  two_recom: AMAS.Recommender
  
  Returns
  -------
  :float
    kappa statistic
  """
  # subjects
  com_ids = list(set(one_recom.species.exist_annotation.keys()).intersection(two_recom.species.exist_annotation.keys()))
  N = len(com_ids)
  # n: number of raters
  n = 2
  Nn = N*n

  # collect unique chebi terms
  chebis1 = set(itertools.chain(*[val[1] for val in list(one_recom.species.exist_annotation.items()) \
                                 if val[0] in com_ids]))
  chebis2 = set(itertools.chain(*[val[1] for val in list(two_recom.species.exist_annotation.items()) \
                                 if val[0] in com_ids]))
  chebis = list(chebis1.union(chebis2))
  k = len(chebis)

  # create df
  df = pd.DataFrame(np.zeros((len(com_ids), len(chebis))))
  df.index=com_ids
  df.columns=chebis
  print(df.shape)
  for one_id in df.index:
    df.loc[one_id, one_recom.species.exist_annotation[one_id][0]] += 1
    df.loc[one_id, two_recom.species.exist_annotation[one_id][0]] += 1  
  # p_j
  pjs = df.sum(0) / Nn

  # P_i
  pis = [(np.sum([val**2 for val in df.loc[one_i,:]])-2)/2 for one_i in df.index]

  pbar = np.sum(pis)/N
  pebar = np.sum([val**2 for val in pjs])

  kappa = (pbar-pebar)/(1-pebar)
  return kappa

# %%
getFleiss(one_recom=recom2, two_recom=recom1)
# Out:
# (516, 438)
# 0.22658061697968174

# %%
p = libsbml.parseFormula ('k1 / s1')
print(libsbml.writeMathMLToString (p))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <apply>
#     <divide/>
#     <ci> k1 </ci>
#     <ci> s1 </ci>
#   </apply>
# </math>

# %%
s = libsbml.writeMathMLToString (p)
s
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<math xmlns="http://www.w3.org/1998/Math/MathML">\n  <apply>\n    <divide/>\n    <ci> k1 </ci>\n    <ci> s1 </ci>\n  </apply>\n</math>'

# %%
getFleiss(one_recom=recom1, two_recom=recom3)
# Out:
# (514, 426)
# 0.22667281698003802

# %%
getFleiss(one_recom=recom3, two_recom=recom3)
# Out:
# (580, 471)
# 1.0

# %%
print([ag1, ag2, ag3])
# Out:
# ['Abiotrophia_defectiva_ATCC_49176.xml', 'Acaricomes_phytoseiuli_DSM_14247.xml', 'Acetanaerobacterium_elongatum_CGMCC_1_5012.xml']

# %%
Counter([k[1] for k in [val for val in tups[0] if val[2]=='CHEBI:1']])
# Out:
# Counter({'10-Formyltetrahydrofolate': 1,
#          '(S)-propane-1,2-diol': 1,
#          '3-Phospho-D-glyceroyl phosphate': 1,
#          '1-acyl-sn-glycerol 3-phosphate(2-)': 1,
#          '1-Pyrroline-5-carboxylate': 1,
#          '(S)-2-[5-Amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxamido]succinate': 1,
#          'L-2-amino-3-oxobutanoic acid': 1,
#          '2-Deoxy-D-ribose 1-phosphate': 1,
#          '2-deoxy-D-ribose 5-phosphate(2-)': 1,
#          '2-methylacetoacetyl-CoA(4-)': 1,
#          '2-methylbutanoyl-CoA(4-)': 1,
#          '2-methyl-3-oxopropanoate': 1,
#          '2-Oxobutanoate': 1,
#          'D-Glycerate 2-phosphate': 1,
#          '2-phosphonatoglycolate(3-)': 1,
#          '3-(4-hydroxyphenyl)pyruvate': 1,
#          '(S)-3-hydroxybutanoyl-CoA(4-)': 1,
#          '(S)-3-Hydroxydecanoyl-CoA': 1,
#          '(S)-3-Hydroxydodecanoyl-CoA': 1,
#          '(2S,3S)-3-hydroxy-2-methylbutanoyl-CoA(4-)': 1,
#          '3-hydroxy-2-methylpropanoate': 1,
#          '(S)-3-Hydroxytetradecanoyl-CoA': 1,
#          '3-methylbut-2-enoyl-CoA(4-)': 1,
#          'trans-3-methylglutaconyl-CoA(5-)': 1,
#          '3-methyl-2-oxobutanoate': 1,
#          '3-methyl-2-oxopentanoate': 1,
#          '3-Oxodecanoyl-CoA': 1,
#          '3-Oxododecanoyl-CoA': 1,
#          '3-oxopalmitoyl-CoA(4-)': 1,
#          '3-Oxotetradecanoyl-CoA': 1,
#          '3-Phospho-D-glycerate': 1,
#          '3-phosphonatooxypyruvate(3-)': 1,
#          '4-Aminobutanoate': 2,
#          '4-Aminobutanal': 1,
#          '4-hydroxy-2-oxoglutarate(2-)': 1,
#          '4-hydroxybenzoate': 1,
#          '4-methyl-2-oxopentanoate': 1,
#          'D-4-Phosphopantothenate': 1,
#          'N-((R)-4-Phosphopantothenoyl)-L-cysteine': 1,
#          '5-amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxylate': 1,
#          '5-Formiminotetrahydrofolate': 1,
#          '5-formyltetrahydrofolate(2-)': 1,
#          '5-Methylthio-5-deoxy-D-ribose 1-phosphate': 1,
#          '5-Methylthio-5-deoxy-D-ribulose 1-phosphate': 1,
#          '5-Methylthioadenosine': 1,
#          '5-Methyltetrahydrofolate': 1,
#          'acyl carrier protein': 1,
#          '4-nitrophenyl phosphate(2-)': 1,
#          'oxalatosuccinate(3-)': 1,
#          'L-Arogenate': 1,
#          'Acetoacetyl-CoA': 1,
#          'ammonioacetone': 1,
#          'L-arabinitol': 1,
#          'Acetate': 2,
#          'Acetoacetate': 1,
#          'Acetaldehyde': 2,
#          'Acetyl-CoA': 1,
#          'N-Acetyl-D-glucosamine 1-phosphate': 1,
#          'N-acetyl-D-glucosamine 6-phosphate(2-)': 1,
#          'N-acetyl-D-glucosamine': 1,
#          'N-acetyl-D-mannosamine': 1,
#          'N-acetyl-D-mannosamine 6-phosphate(2-)': 1,
#          'N-acetylneuraminate': 1,
#          'Adenine': 1,
#          'Adenosine': 1,
#          'Adenosylcobalamin': 2,
#          'ADP': 1,
#          'ADP alpha-D-glucoside(2-)': 1,
#          'agmatinium(2+)': 1,
#          'S-Adenosyl-L-homocysteine': 1,
#          '7,8-dihydroneopterin 3-triphosphate(4-)': 1,
#          '5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide': 1,
#          '5-amino-1-(5-phospho-D-ribosyl)imidazole': 1,
#          '2-Oxoglutarate': 1,
#          'D-alanine': 1,
#          'L-alanine': 2,
#          'D-Alanyl-D-alanine': 1,
#          'L-alanyl-L-histidine': 2,
#          'S-Adenosyl-L-methionine': 1,
#          'S-Adenosylmethioninamine': 1,
#          'AMP': 1,
#          'L-arabinose': 2,
#          'L-arginine': 2,
#          'N(omega)-(L-Arginino)succinate': 1,
#          'L-asparagine': 1,
#          'L-aspartate': 1,
#          'ATP': 1,
#          'Biotin': 1,
#          'calcium(2+)': 2,
#          '3,5-cyclic AMP(1-)': 1,
#          'N-Carbamoyl-L-aspartate': 1,
#          'Cob(I)alamin': 2,
#          'Cob(II)alamin': 2,
#          'Carbamoyl phosphate': 1,
#          'CDP': 1,
#          'L-cysteinylglycine': 2,
#          'Choline': 1,
#          'Citrate': 2,
#          'Chloride': 2,
#          'CMP': 1,
#          'CMP-N-acetyl-beta-neuraminate(2-)': 1,
#          'Carbon dioxide': 2,
#          'Coenzyme A': 1,
#          'Coproporphyrinogen III': 1,
#          'CTP': 1,
#          'L-cysteine': 1,
#          'L-cystathionine': 1,
#          'Cytidine': 1,
#          '2-deoxyadenosine': 1,
#          'dADP': 1,
#          'dAMP(2-)': 1,
#          'dATP': 1,
#          'N6-(1,2-Dicarboxyethyl)-AMP': 1,
#          'dCDP': 1,
#          'dCMP': 1,
#          'dCTP': 1,
#          'Deoxycytidine': 1,
#          'Dodecanoyl-ACP (n-C12:0ACP)': 1,
#          'laurate': 1,
#          'dGDP': 1,
#          'dGMP': 1,
#          'Deoxyguanosine': 1,
#          'dGTP': 1,
#          'glycerone': 1,
#          'Dihydroxyacetone phosphate': 1,
#          '7,8-Dihydrofolate': 1,
#          'dihydrolipoamide': 1,
#          '(S)-dihydroorotate': 1,
#          'Deoxyinosine': 1,
#          'Dimethylallyl diphosphate': 1,
#          'Deamino-NAD+': 1,
#          'Dephospho-CoA': 1,
#          '2-deoxy-D-ribose': 2,
#          'dTDP-4-dehydro-6-deoxy-alpha-D-glucose(2-)': 1,
#          'dTDP-4-dehydro-6-deoxy-L-mannose(2-)': 1,
#          'dTDP': 1,
#          'dTDP-glucose(2-)': 1,
#          'dTDP-L-rhamnose': 1,
#          'dTMP': 1,
#          'dTTP': 1,
#          'dUDP': 1,
#          'dUMP': 1,
#          'Deoxyuridine': 1,
#          'dUTP': 1,
#          'erythro-4-hydroxy-L-glutamate(1-)': 1,
#          'D-Erythrose 4-phosphate': 1,
#          'Ethanolamine': 1,
#          'Ethanol': 2,
#          'D-Fructose 1-phosphate': 1,
#          'D-Fructose 6-phosphate': 1,
#          'Flavin adenine dinucleotide oxidized': 1,
#          'Flavin adenine dinucleotide reduced': 1,
#          'D-Fructose 1,6-bisphosphate': 1,
#          'Fe2+': 2,
#          'Fe3+': 2,
#          'N2-Formyl-N1-(5-phospho-D-ribosyl)glycinamide': 1,
#          'Ferricytochrome c': 1,
#          'FMN': 1,
#          'Ferrocytochrome C': 1,
#          'Folate': 2,
#          'Formate': 2,
#          '2-(Formamido)-N1-(5-phospho-D-ribosyl)acetamidine': 1,
#          '5-Formamido-1-(5-phospho-D-ribosyl)imidazole-4-carboxamide': 1,
#          'Farnesyl diphosphate': 1,
#          'D-Fructose': 1,
#          'L-fucose': 1,
#          'Fumarate': 1,
#          'D-Glucose 1-phosphate': 1,
#          'Glyceraldehyde 3-phosphate': 1,
#          'sn-Glycero-3-phosphocholine': 1,
#          'D-Glucose 6-phosphate': 1,
#          'D-galactopyranose 1-phosphate': 1,
#          'D-Galactose': 2,
#          'D-Glucosamine 6-phosphate': 1,
#          'N1-(5-Phospho-D-ribosyl)glycinamide': 1,
#          'GDP': 1,
#          '2-trans,6-trans,10-trans-geranylgeranyl diphosphate(3-)': 1,
#          'D-glucose': 2,
#          'L-glutamine': 2,
#          'L-Glutamate 5-phosphate': 1,
#          'L-Glutamate 5-semialdehyde': 1,
#          'L-glutamate': 2,
#          'glyoxylate': 1,
#          'Glycine': 2,
#          'D-Glyceraldehyde': 1,
#          'glycine betaine': 2,
#          'Glycerol 3-phosphate': 2,
#          'Glycerol': 1,
#          'D-glycerate': 1,
#          'glycolate': 1,
#          'Glycylleucine': 2,
#          'Glycylproline': 2,
#          'GMP': 1,
#          'Geranyl diphosphate': 1,
#          'Guanosine': 1,
#          'Reduced glutathione': 1,
#          'GTP': 1,
#          'Guanine': 1,
#          'Hydrogen peroxide': 1,
#          'Water': 2,
#          'proton': 2,
#          'Bicarbonate': 1,
#          'L-homocysteine': 1,
#          'Hexadecanoate (n-C16:0)': 1,
#          'Hexadecenoate (n-C16:1)': 1,
#          'L-histidine': 1,
#          'L-homoserine': 1,
#          'Hypoxanthine': 2,
#          'isobutyryl-CoA(4-)': 1,
#          'Isocitrate': 1,
#          'IDP(3-)': 1,
#          'L-isoleucine': 2,
#          'imidazol-4-ylacetate': 1,
#          'imidazole-4-acetaldehyde': 1,
#          'IMP': 1,
#          'Inosine': 1,
#          'Isopentenyl diphosphate': 1,
#          'ITP(3-)': 1,
#          'Isovaleryl-CoA': 1,
#          'potassium': 2,
#          'D-lactate': 2,
#          'L-lactate': 2,
#          '(S)-lactaldehyde': 1,
#          'Lactose': 2,
#          'L-leucine': 2,
#          '(R)-S-lactoylglutathionate(1-)': 1,
#          'lipoamide': 1,
#          'L-lysine': 1,
#          'Malonyl-[acyl-carrier protein]': 1,
#          'L-malate': 1,
#          'Malonyl-CoA': 1,
#          'Maltose': 2,
#          'Maltohexaose': 2,
#          'maltopentaose': 1,
#          'maltotriose': 2,
#          'Maltotetraose': 1,
#          'D-Mannose 6-phosphate': 1,
#          'methanol': 1,
#          'L-methionine': 2,
#          'L-methionyl-L-alanine': 2,
#          '5,10-Methenyltetrahydrofolate': 1,
#          '5,10-Methylenetetrahydrofolate': 1,
#          'Menaquinone 8': 2,
#          'methylglyoxal': 1,
#          'Myristoyl-ACP (n-C14:0ACP)': 1,
#          'Sodium': 2,
#          'Nicotinate': 2,
#          'Nicotinamide adenine dinucleotide': 1,
#          'Nicotinamide adenine dinucleotide - reduced': 1,
#          'Nicotinamide adenine dinucleotide phosphate': 1,
#          'Nicotinamide adenine dinucleotide phosphate - reduced': 1,
#          'Nicotinamide': 1,
#          'Ammonium': 2,
#          'Nicotinate D-ribonucleoside': 1,
#          'Nicotinate D-ribonucleotide': 1,
#          'NMN': 1,
#          'O2': 2,
#          'superoxide': 1,
#          'Oxaloacetate': 1,
#          'octadecanoate (n-C18:0)': 2,
#          'octadecenoate (n-C18:1)': 1,
#          'Octadecenoyl-CoA (n-C18:1CoA)': 1,
#          'Ornithine': 2,
#          'Orotidine 5-phosphate': 1,
#          'Orotate': 1,
#          'oxalate(2-)': 1,
#          'Palmitoyl-ACP (n-C16:0ACP)': 1,
#          'Pantetheine 4-phosphate': 1,
#          'adenosine 3,5-bismonophosphate(4-)': 1,
#          'Pyridoxine 5-phosphate': 1,
#          'Phosphoenolpyruvate': 1,
#          'L-phenylalanine': 2,
#          'Protoheme': 2,
#          'O-phosphonato-L-homoserine(2-)': 1,
#          'keto-phenylpyruvate': 1,
#          'hydrogenphosphate': 2,
#          'Palmitoyl-CoA (n-C16:0CoA)': 1,
#          '(R)-Pantothenate': 2,
#          'Propionate': 1,
#          'Propanoyl-CoA': 1,
#          'Diphosphate': 1,
#          'Protoporphyrinogen IX': 1,
#          'triphosphate(5-)': 1,
#          '5-Phospho-beta-D-ribosylamine': 1,
#          'L-proline': 2,
#          '5-Phospho-alpha-D-ribose 1-diphosphate': 1,
#          'phosphatidylserine (didodecanoyl, n-C12:0)': 1,
#          'O-Phospho-L-serine': 1,
#          'Putrescine': 1,
#          'pantetheine': 1,
#          'Pyridoxamine 5-phosphate': 1,
#          'Pyridoxamine': 1,
#          'Pyridoxal 5-phosphate': 1,
#          'Pyridoxal': 2,
#          'Pyridoxine': 2,
#          'Pyruvate': 1,
#          'quinolinate(2-)': 1,
#          'alpha-D-Ribose 1-phosphate': 1,
#          'alpha-D-Ribose 5-phosphate': 1,
#          'D-ribulose': 1,
#          'D-ribose': 2,
#          'Riboflavin': 2,
#          'N-Ribosylnicotinamide': 1,
#          'D-ribulose 5-phosphate(2-)': 1,
#          'Sedoheptulose 7-phosphate': 1,
#          'Selenide': 1,
#          'Selenophosphate': 1,
#          'L-serine': 1,
#          'Sulfite': 1,
#          'sulfate': 2,
#          'Spermidine': 2,
#          'Stearoyl-CoA (n-C18:0CoA)': 1,
#          'Succinate': 2,
#          'Sucrose': 2,
#          'Taurine': 2,
#          'Tetradecanoyl-CoA (n-C14:0CoA)': 1,
#          '5,6,7,8-Tetrahydrofolate': 1,
#          'Thiamin': 2,
#          'Thiamin monophosphate': 1,
#          'Thiamine diphosphate': 1,
#          'L-threonine': 1,
#          'Thymidine': 2,
#          'Oxidized thioredoxin': 1,
#          'Reduced thioredoxin': 1,
#          'Trehalose': 2,
#          'L-tryptophan': 2,
#          'thiosulfate(2-)': 1,
#          'trans,trans,cis-Geranylgeranyl diphosphate': 1,
#          'tetradecanoate (n-C14:0)': 1,
#          'tetradecenoate (n-C14:1)': 1,
#          'L-tyrosine': 1,
#          'UDP-N-acetyl-alpha-D-glucosamine(2-)': 1,
#          'UDP': 1,
#          'UDP-N-acetyl-D-galactosamine(2-)': 1,
#          'UDPglucose': 1,
#          'UDP-D-galactose(2-)': 1,
#          'UMP': 1,
#          'uracil': 1,
#          'Uridine': 1,
#          'UTP': 1,
#          'L-valine': 2,
#          'Xanthine': 1,
#          'Xanthosine 5-phosphate': 1,
#          'xanthosine': 1,
#          'D-xylulose 5-phosphate(2-)': 1,
#          'aldehydo-D-xylose': 2,
#          'D-xylulose': 1,
#          'L-xylulose': 1})

# %%
def getIdFromName(inp_name):
  # should be a display name
  filt_s = [val[0] for val in specs if val[1]==inp_name]
  return filt_s

# %%
getIdFromName('10-formyltetrahydrofolate')
# Out:
# []

# %%
filt_s = [val[0] for val in specs if val[1]=='10-Formyltetrahydrofolate']
filt_s
# Out:
# ['M_10fthf__91__c__93__']

# %%
inp_name = '10-Formyltetrahydrofolate'
filt_s = [val[0] for val in specs if val[1]==inp_name]
filt_s[0]
# Out:
# 'M_10fthf__91__c__93__'

# %%
recom.species.exist_annotation['10-formyltetrahydrofolate']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 recom.species.exist_annotation['10-formyltetrahydrofolate']
#
# KeyError: '10-formyltetrahydrofolate'

# %%
spec_dict
# Out:
# {'10-formyltetrahydrofolate-[Glu](5)': 1,
#  '10-Formyltetrahydrofolate': 1,
#  '10-methyl-3-hydroxy-dodecanoyl-ACP': 1,
#  '10-methyl-3-hydroxy-undecanoyl-ACP': 1,
#  '10-methyl-3-oxo-dodecanoyl-ACP': 1,
#  '10-methyl-3-oxo-undecanoyl-ACP': 1,
#  '10-methyl-dodecanoyl-ACP': 1,
#  '10-methyl-trans-dodec-2-enoyl-ACP': 1,
#  '10-methyl-trans-undec-2-enoyl-ACP': 1,
#  '10-methyl-undecanoyl-ACP': 1,
#  '11-methyl-3-hydroxy-dodecanoyl-ACP': 1,
#  '11-methyl-3-oxo-dodecanoyl-ACP': 1,
#  '11-methyl-dodecanoyl-ACP': 1,
#  '11-methyl-trans-dodec-2-enoyl-ACP': 1,
#  '12-methyl-3-hydroxy-tetra-decanoyl-ACP': 1,
#  '12-methyl-3-hydroxy-tridecanoyl-ACP': 1,
#  '12-methyl-3-oxo-tetra-decanoyl-ACP': 1,
#  '12-methyl-3-oxo-tridecanoyl-ACP': 1,
#  '12-methyl-tetra-decanoyl-ACP': 1,
#  '12-methyl-trans-tetra-dec-2-enoyl-ACP': 1,
#  '12-methyl-tridecanoyl-ACP': 1,
#  '12-methyl-trans-tridec-2-enoyl-ACP': 1,
#  '3-Phospho-D-glyceroyl phosphate': 1,
#  '13-methyl-3-hydroxy-tetra-decanoyl-ACP': 1,
#  '13-methyl-3-oxo-tetra-decanoyl-ACP': 1,
#  '13-methyl-tetra-decanoyl-ACP': 1,
#  '13-methyl-trans-tetra-dec-2-enoyl-ACP': 1,
#  '14-methyl-3-hydroxy-hexa-decanoyl-ACP': 1,
#  '14-methyl-3-hydroxy-pentadecanoyl-ACP': 1,
#  '14-methyl-3-oxo-hexa-decanoyl-ACP': 1,
#  '14-methyl-3-oxo-pentadecanoyl-ACP': 1,
#  '14-methyl-hexa-decanoyl-ACP': 1,
#  '14-methyl-pentadecanoyl-ACP': 1,
#  '14-methyl-trans-hexa-dec-2-enoyl-ACP': 1,
#  '14-methyl-trans-pentadec-2-enoyl-ACP': 1,
#  '15-methyl-3-hydroxy-hexa-decanoyl-ACP': 1,
#  '15-methyl-3-oxo-hexa-decanoyl-ACP': 1,
#  '15-methyl-hexa-decanoyl-ACP': 1,
#  '15-methyl-trans-hexa-dec-2-enoyl-ACP': 1,
#  '15-cis-Phytoene': 1,
#  '1-anteisoheptadecanoyl-sn-glycerol 3-phosphate (14-methyl-hexadecanoyl, anteiso-C17)': 1,
#  '1-anteisopentadecanoyl-sn-glycerol 3-phosphate (12-methyl-tetradecanoyl, anteiso-C15)': 1,
#  '1-acyl-sn-glycerol 3-phosphate(2-)': 1,
#  '1-hexadec-9-enoyl-sn-glycerol 3-phosphate': 1,
#  '1-hexadecanoyl-sn-glycerol 3-phosphate': 1,
#  '1-isohexadecanoyl-sn-glycerol 3-phosphate (14-methyl-pentadecanoyl, iso-C16)': 1,
#  '1-isoheptadecanoyl-sn-glycerol 3-phosphate (15-methyl-hexadecanoyl, iso-C17)': 1,
#  '1-isopentadecanoyl-sn-glycerol 3-phosphate (13-methyl-tetradecanoyl, iso-C15)': 1,
#  '1-isotetradecanoyl-sn-glycerol 3-phosphate (12-methyl-tridecanoyl, iso-C14)': 1,
#  '1-octadec-11-enoyl-sn-glycerol 3-phosphate': 1,
#  '1-octadecanoyl-sn-glycerol 3-phosphate': 1,
#  'L-1-Pyrroline-3-hydroxy-5-carboxylate': 1,
#  '1-Pyrroline-5-carboxylate': 1,
#  '1-tetradec-7-enoyl-sn-glycerol 3-phosphate': 1,
#  '1-tetradecanoyl-sn-glycerol 3-phosphate': 1,
#  '(R)-2,3-Dihydroxy-3-methylbutanoate': 1,
#  '(R)-2,3-Dihydroxy-3-methylpentanoate': 1,
#  '(S)-2-[5-Amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxamido]succinate': 1,
#  '2,5-Diamino-6-hydroxy-4-(5-phosphoribosylamino)-pyrimidine': 1,
#  'LL-2,6-Diaminoheptanedioate': 1,
#  'meso-2,6-Diaminoheptanedioate': 2,
#  '(S)-2-Aceto-2-hydroxybutanoate': 1,
#  '2-Amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine diphosphate': 1,
#  '2-Amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine': 1,
#  'L-2-amino-3-oxobutanoic acid': 1,
#  '1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate': 1,
#  '2-Dehydro-3-deoxy-D-arabino-heptonate 7-phosphate': 1,
#  '2-Dehydropantoate': 1,
#  '2-Demethylmenaquinone 8': 1,
#  '2-Demethylmenaquinol 8': 1,
#  '2-Deoxy-D-ribose 1-phosphate': 1,
#  '2-deoxy-D-ribose 5-phosphate(2-)': 1,
#  '2-Inosose': 1,
#  '2-Isopropylmaleate': 1,
#  '2-Methyl-1-hydroxybutyl-TPP': 1,
#  '2-Methyl-1-hydroxypropyl-TPP': 1,
#  '2-methylacetoacetyl-CoA(4-)': 1,
#  '2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphate': 1,
#  '2-methylcrotonoyl-CoA(4-)': 1,
#  '2-methylbutanoyl-CoA(4-)': 1,
#  '2-methylbutanoyl-ACP,2-methylbutyryl-ACP': 1,
#  '(Z)-but-2-ene-1,2,3-tricarboxylate': 1,
#  '2-methylcitrate(3-)': 1,
#  '2-C-methyl-D-erythritol 4-phosphate': 1,
#  '2-C-methyl-D-erythritol 2,4-cyclodiphosphate': 1,
#  '2-methyl-3-oxopropanoate': 1,
#  '2-Methylprop-2-enoyl-CoA': 1,
#  'S-(2-Methylpropanoyl)-dihydrolipoamide': 1,
#  '2-methylpropionyl-ACP,isobutyryl-ACP': 1,
#  '2-Oxobutanoate': 1,
#  '2-Octaprenyl-6-hydroxyphenol': 1,
#  '2-Octaprenyl-6-methoxy-1,4-benzoquinol': 1,
#  '2-Octaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinol': 1,
#  '2-Octaprenyl-3-methyl-6-methoxy- 1,4-benzoquinol': 1,
#  '2-Octaprenyl-6-methoxyphenol': 1,
#  '2-Octaprenylphenol': 1,
#  '2-phospho-4-(cytidine 5-diphospho)-2-C-methyl-D-erythritol': 1,
#  'D-Glycerate 2-phosphate': 1,
#  '2-Succinyl-5-enolpyruvyl-6-hydroxy-3-cyclohexene-1-carboxylate': 1,
#  '2-Succinyl-6-hydroxy-2,4-cyclohexadiene-1-carboxylate': 1,
#  '2-Oxo-3-hydroxyisovalerate': 1,
#  '(3,4-dihydroxyphenyl)acetate': 2,
#  '3-(4-hydroxyphenyl)pyruvate': 1,
#  '3-Carboxy-2-hydroxy-4-methylpentanoate': 1,
#  '3-Carboxy-3-hydroxy-4-methylpentanoate': 1,
#  '3-Carboxy-4-methyl-2-oxopentanoate': 1,
#  '3-Dehydroquinate': 1,
#  '3-Dehydroshikimate': 1,
#  '(R)-3-Hydroxy-3-methyl-2-oxopentanoate': 1,
#  '(3R)-3-Hydroxyacyl-[acyl-carrier protein]': 1,
#  '(3S)-3-Hydroxyadipyl-CoA': 1,
#  '3-hydroxyanthranilate': 1,
#  '(S)-3-hydroxybutanoyl-CoA(4-)': 1,
#  '(R)-3-hydroxybutanoyl-CoA(4-)': 1,
#  '(S)-3-Hydroxydecanoyl-CoA': 1,
#  '(S)-3-Hydroxydodecanoyl-CoA': 1,
#  '(R)-3-Hydroxydodecanoyl-[acyl-carrier protein]': 1,
#  '(R)-3-Hydroxydecanoyl-[acyl-carrier protein]': 1,
#  '(S)-3-Hydroxyhexanoyl-CoA': 1,
#  '(S)-3-Hydroxyhexadecanoyl-CoA': 1,
#  '(R)-3-Hydroxyhexanoyl-[acyl-carrier protein]': 1,
#  '(S)-3-Hydroxyisobutyryl-CoA': 1,
#  '(2S,3S)-3-hydroxy-2-methylbutanoyl-CoA(4-)': 1,
#  '3-hydroxy-2-methylpropanoate': 1,
#  '(R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]': 1,
#  '(S)-3-Hydroxyoctanoyl-CoA': 1,
#  '(R)-3-Hydroxyoctanoyl-[acyl-carrier protein]': 1,
#  '(R)-3-Hydroxyoctadecanoyl-[acyl-carrier protein]': 1,
#  'R-3-hydroxypalmitoyl-[acyl-carrier protein]': 1,
#  '3-hydroxypropanoyl-CoA(4-)': 1,
#  '3-Hydroxyphenylacetate': 2,
#  '(S)-3-Hydroxytetradecanoyl-CoA': 1,
#  'C-(3-Indolyl)-glycerol 3-phosphate': 1,
#  '3-Methyl-1-hydroxybutyl-TPP': 1,
#  '3-methylbut-2-enoyl-CoA(4-)': 1,
#  '3-methylbutanoyl-ACP,isovaleryl-ACP': 1,
#  'trans-3-methylglutaconyl-CoA(5-)': 1,
#  '3-methyl-2-oxobutanoate': 1,
#  '3-methyl-2-oxopentanoate': 1,
#  '3-Oxodecanoyl-CoA': 1,
#  '3-Oxododecanoyl-CoA': 1,
#  '3-Oxododecanoyl-[acyl-carrier protein]': 1,
#  '3-Oxodecanoyl-[acyl-carrier protein]': 1,
#  '3-Oxohexanoyl-CoA': 1,
#  '3-oxopalmitoyl-CoA(4-)': 1,
#  '3-Oxohexanoyl-[acyl-carrier protein]': 1,
#  '3-Oxotetradecanoyl-[acyl-carrier protein]': 1,
#  '3-Oxooctanoyl-CoA': 1,
#  '3-Oxooctanoyl-[acyl-carrier protein]': 1,
#  '3-Oxooctadecanoyl-[acyl-carrier protein]': 1,
#  '3-Oxohexadecanoyl-[acyl-carrier protein]': 1,
#  '3-Octaprenyl-4-hydroxybenzoate': 1,
#  '3-Oxotetradecanoyl-CoA': 1,
#  '3-Phospho-D-glycerate': 1,
#  '3-phosphonatooxypyruvate(3-)': 1,
#  '5-O-(1-Carboxyvinyl)-3-phosphoshikimate': 1,
#  '4-Aminobutanoate': 1,
#  '4-Aminobutanal': 1,
#  '4-Aminobenzoate': 1,
#  '4-amino-4-deoxychorismate': 1,
#  '4-Amino-5-hydroxymethyl-2-methylpyrimidine': 1,
#  '4-Amino-2-methyl-5-phosphomethylpyrimidine': 1,
#  '4-(cytidine 5-diphospho)-2-C-methyl-D-erythritol': 1,
#  '4-Guanidinobutanoate': 1,
#  '4-Guanidinobutanamide': 1,
#  '4-hydroxy-2-oxoglutarate(2-)': 1,
#  '4-Hydroxy-benzyl alcohol': 1,
#  '4-hydroxybenzoate': 2,
#  '4-hydroxyphenylacetate': 1,
#  'trans-4-hydroxy-L-proline': 1,
#  '4-Hydroxy-L-threonine': 1,
#  '4-Imidazolone-5-propanoate': 1,
#  '4-methyl-3-hydroxy-hexanoyl-ACP': 1,
#  '4-methyl-3-hydroxy-pentanoyl-ACP': 1,
#  '4-methyl-3-oxo-hexanoyl-ACP': 1,
#  '4-methyl-3-oxo-pentanoyl-ACP': 1,
#  '4-methyl-hexanoyl-ACP': 1,
#  '4-methyl-2-oxopentanoate': 1,
#  '4-methyl-pentanoyl-ACP': 1,
#  '4-Methyl-5-(2-phosphoethyl)-thiazole': 1,
#  '4-methyl-trans-hex-2-enoyl-ACP': 1,
#  '4-methyl-trans-pent-2-enoyl-ACP': 1,
#  '4-Phospho-L-aspartate': 1,
#  '4-Phospho-D-erythronate': 1,
#  'D-4-Phosphopantothenate': 1,
#  'N-((R)-4-Phosphopantothenoyl)-L-cysteine': 1,
#  '4-(1-D-Ribitylamino)-5-aminouracil': 1,
#  '5-amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxylate': 1,
#  '5-Amino-4-oxopentanoate': 1,
#  '5-Amino-6-(5-phosphoribitylamino)uracil': 1,
#  '5-Amino-6-(5-phosphoribosylamino)uracil': 1,
#  '5-deoxyribose': 1,
#  '5-formyltetrahydrofolate(2-)': 1,
#  '5-methyl-3-hydroxy-hexanoyl-ACP': 1,
#  '5-methyl-3-oxo-hexanoyl-ACP': 1,
#  '5-methyl-hexanoyl-ACP': 1,
#  '5-Methylthioadenosine': 1,
#  '5-methyl-trans-hex-2-enoyl-ACP': 1,
#  '5-Methyltetrahydrofolate': 1,
#  'N1-(5-Phospho-alpha-D-ribosyl)-5,6-dimethylbenzimidazole': 1,
#  '6-methyl-3-hydroxy-heptanoyl-ACP': 1,
#  '6-methyl-3-hydroxy-octanoyl-ACP': 1,
#  '6-methyl-3-oxo-heptanoyl-ACP': 1,
#  '6-methyl-3-oxo-octanoyl-ACP': 1,
#  '6-methyl-heptanoyl-ACP': 1,
#  '6-methyl-octanoyl-ACP': 1,
#  '6-methyl-trans-hept-2-enoyl-ACP': 1,
#  '6-methyl-trans-oct-2-enoyl-ACP': 1,
#  '6-Phospho-D-gluconate': 1,
#  '6-phospho-D-glucono-1,5-lactone': 1,
#  '7-methyl-3-hydroxy-octanoyl-ACP': 1,
#  '7-methyl-3-oxo-octanoyl-ACP': 1,
#  '7-methyl-octanoyl-ACP': 1,
#  '7-methyl-trans-oct-2-enoyl-ACP': 1,
#  '8-methyl-3-hydroxy-decanoyl-ACP': 1,
#  '8-methyl-3-hydroxy-nonanoyl-ACP': 1,
#  '8-methyl-3-oxo-decanoyl-ACP': 1,
#  '8-methyl-3-oxo-nonanoyl-ACP': 1,
#  '8-methyl-decanoyl-ACP': 1,
#  '8-methyl-nonanoyl-ACP': 1,
#  '8-methyl-trans-dec-2-enoyl-ACP': 1,
#  '8-methyl-trans-non-2-enoyl-ACP': 1,
#  '9-methyl-3-hydroxy-decanoyl-ACP': 1,
#  '9-methyl-3-oxo-decanoyl-ACP': 1,
#  '9-methyl-decanoyl-ACP': 1,
#  '9-methyl-trans-dec-2-enoyl-ACP': 1,
#  'acyl carrier protein': 1,
#  'lipoyl-AMP(1-)': 1,
#  'S-Succinyldihydrolipoamide': 1,
#  'L-3-Cyanoalanine': 1,
#  '4-nitrophenyl phosphate(2-)': 1,
#  'S-(2-Methylbutanoyl)-dihydrolipoamide': 1,
#  'S-(3-Methylbutanoyl)-dihydrolipoamide': 1,
#  'oxalatosuccinate(3-)': 1,
#  '3-Carboxy-1-hydroxypropyl-ThPP': 1,
#  'gamma-Glutamyl-beta-cyanoalanine': 1,
#  'UroporphyrinogenI': 1,
#  'Formamidopyrimidine nucleoside triphosphate': 1,
#  '2,5-Diaminopyrimidine nucleoside triphosphate': 1,
#  'Propinol adenylate': 1,
#  'gamma-Glutamyl-3-aminopropiononitrile': 1,
#  '2,5-Diamino-6-(5-triphosphoryl-3,4-trihydroxy-2-oxopentyl)- amino-4-oxopyrimidine': 1,
#  'L-Arogenate': 1,
#  'N-formyl-L-kynurenine': 1,
#  'Peptidoglycan polymer (n subunits)': 1,
#  'Peptidoglycan polymer (n-1 subunits)': 1,
#  'Acrylamide': 1,
#  'Aminoacetaldehyde': 1,
#  'Acetoacetyl-CoA': 1,
#  'L-arabinitol': 1,
#  'Acetyl-ACP': 1,
#  'Acetate': 2,
#  'Acetoacetate': 1,
#  'Acetaldehyde': 1,
#  'N-Acetyl-beta-D-mannosaminyl-1,4-N-acetyl-D- glucosaminyldiphosphoundecaprenol': 1,
#  'Acetyl-CoA': 1,
#  'N-acetyl-L-gamma-glutamyl phosphate(3-)': 1,
#  '2-acetamido-5-oxopentanoate': 1,
#  'N-Acetyl-D-glucosamine 1-phosphate': 1,
#  'N-acetyl-D-glucosamine 6-phosphate(2-)': 1,
#  'N-acetyl-D-glucosamine': 2,
#  'N-acetyl-L-glutamate(2-)': 1,
#  'O-Acetyl-L-homoserine': 1,
#  'Acetyl-maltose': 1,
#  'cis-Aconitate': 1,
#  'trans-Aconitate': 1,
#  'E-3-carboxy-2-pentenedioate 6-methyl ester': 1,
#  'N(2)-acetyl-L-ornithine': 1,
#  'acrylate': 1,
#  'O-Acetyl-L-serine': 1,
#  'Acetoacetyl-ACP': 1,
#  'Acetyl phosphate': 1,
#  'Acetamide': 1,
#  'Adenine': 1,
#  'S-Acetyldihydrolipoamide': 1,
#  'Adenosine': 1,
#  'Adenosyl cobinamide': 1,
#  'Adenosyl cobinamide phosphate': 1,
#  'Adenosylcobalamin': 2,
#  'ADP': 1,
#  'ADPribose': 1,
#  'Adenosine-GDP-cobinamide': 1,
#  'agmatinium(2+)': 1,
#  'S-Adenosyl-L-homocysteine': 1,
#  '7,8-dihydroneopterin 3-triphosphate(4-)': 1,
#  'Anteisopentadecanoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Anteisopentadecanoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  'Anteisoheptadecanoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Anteisoheptadecanoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  '5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide': 1,
#  'fa12coa,Anteiso-C17:0 CoA   Anteisoheptadecanoyl-CoA': 1,
#  'fa4coa,Anteiso-C15:0 CoA   Anteisopentadecanoyl-CoA': 1,
#  '5-amino-1-(5-phospho-D-ribosyl)imidazole': 1,
#  '2-Oxoglutarate': 1,
#  'beta-alanine': 1,
#  'D-alanine': 2,
#  'L-alanine': 1,
#  'D-Alanyl-D-alanine': 1,
#  'L-alanyl-L-aspartate': 2,
#  '(S)-2-Acetolactate': 1,
#  'L-alanyl-L-glutamine': 2,
#  'L-alanyl-L-glutamate': 2,
#  'L-alanylglycine': 2,
#  'L-alanyl-L-histidine': 2,
#  'L-alanyl-L-leucine': 2,
#  'L-alanyl-L-threonine': 2,
#  'Allophanate': 1,
#  'Allantoin': 2,
#  'S-Aminomethyldihydrolipoylprotein': 1,
#  'S-Adenosyl-L-methionine': 1,
#  'S-Adenosylmethioninamine': 1,
#  'AMP': 1,
#  'anthranilate': 1,
#  'apoprotein [acyl carrier protein]': 1,
#  'Holocarboxylase (biotin covalent bound to Lys residue of apoC)': 1,
#  'L-arabinose': 2,
#  'Arbutin 6-phosphate': 1,
#  'Arbutin': 1,
#  'L-arginine': 1,
#  'N(omega)-(L-Arginino)succinate': 1,
#  'L-asparagine': 1,
#  'L-aspartate': 1,
#  'L-Aspartate 4-semialdehyde': 1,
#  'all-trans-Nonaprenyl diphosphate; solanesyl diphosphate': 1,
#  'ATP': 1,
#  'crotonoyl-CoA(4-)': 1,
#  'beta-Aminopropion aldehyde': 1,
#  'betaine aldehyde': 1,
#  '(R)-3-hydroxybutyrate': 1,
#  'Produced biomass': 1,
#  'Butanoyl-CoA': 1,
#  'Biotin': 2,
#  'Carboxybiotin-carboxyl-carrier protein': 1,
#  'But-2-enoyl-[acyl-carrier protein]': 1,
#  'Butyryl-ACP (n-C4:0ACP)': 1,
#  'benzoate': 2,
#  'Benzamide': 2,
#  'calcium(2+)': 2,
#  '3,5-cyclic AMP(1-)': 1,
#  'N-Carbamoyl-L-aspartate': 1,
#  'Cobinamide': 1,
#  'Cob(I)alamin': 2,
#  'Cob(II)alamin': 2,
#  'Carbamoyl phosphate': 1,
#  'Cadmium': 2,
#  'CDP': 1,
#  'CDP-1,2-dianteisoheptadecanoylglycerol (14-methyl-hexadecanoyl, anteiso-C17)': 1,
#  'CDP-1,2-dianteisopentadecanoylglycerol (12-methyl-tetradecanoyl, anteiso-C15)': 1,
#  'CDP-1,2-didodecanoylglycerol': 1,
#  'CDP-1,2-dihexadec-9-enoylglycerol': 1,
#  'CDP-1,2-dihexadecanoylglycerol': 1,
#  'CDP-1,2-diisohexadecanoylglycerol (14-methyl-pentadecanoyl, iso-C16)': 1,
#  'CDP-1,2-diisoheptadecanoylglycerol (15-methyl-hexadecanoyl, iso-C17)': 1,
#  'CDP-1,2-diisopentadecanoylglycerol (13-methyl-tetradecanoyl, iso-C15)': 1,
#  'CDP-1,2-diisotetradecanoylglycerol (12-methyl-tridecanoyl, iso-C14)': 1,
#  'CDP-1,2-dioctadec-11-enoylglycerol': 1,
#  'CDP-1,2-dioctadecanoylglycerol': 1,
#  'CDP-1,2-ditetradec-7-enoylglycerol': 1,
#  'CDP-1,2-ditetradecanoylglycerol': 1,
#  'CDPglycerol': 1,
#  'L-cysteinylglycine': 2,
#  'Choline': 2,
#  'chorismate': 1,
#  'N,N-diacetylchitobiose': 1,
#  'Citrate': 1,
#  'L-citrulline': 1,
#  'Chloride': 2,
#  'cardiolipin (tetraoctadecanoyl, n-C18:0)': 1,
#  'cardiolipin (14-methyl-hexadecanoyl, anteiso-C17)': 1,
#  'cardiolipin (15-methyl-hexadecanoyl, iso-C17)': 1,
#  'CMP': 1,
#  'Carbon dioxide': 2,
#  'Coenzyme A': 1,
#  'Co2+': 2,
#  'Coproporphyrinogen I': 1,
#  'Coproporphyrinogen III': 1,
#  'cytosine': 2,
#  'CTP': 1,
#  'Cu2+': 2,
#  'L-cysteine': 1,
#  'L-cystathionine': 1,
#  'Cytidine': 1,
#  '2-deoxyadenosine': 1,
#  '5-Deoxyadenosine': 1,
#  'dADP': 1,
#  'dAMP(2-)': 1,
#  'dATP': 1,
#  '3,4-dihydroxy-2-butanone 4-phosphate': 1,
#  'trans-Dec-2-enoyl-CoA': 1,
#  'Decanoyl-ACP (n-C10:0ACP)': 1,
#  'Decanoyl-CoA (n-C10:0CoA)': 1,
#  'N6-(1,2-Dicarboxyethyl)-AMP': 1,
#  'dCDP': 1,
#  'dCMP': 1,
#  'dCTP': 1,
#  'Deoxycytidine': 1,
#  'trans-Dodec-2-enoyl-CoA': 1,
#  'Dodecanoyl-ACP (n-C12:0ACP)': 1,
#  'Dodecanoyl-CoA (n-C12:0CoA)': 1,
#  'Dextran 40, 1,6-alpha-D-Glucan': 1,
#  'Dextrin': 2,
#  'Gemcitabine': 2,
#  '2,2-Difluorodeoxyuridine': 2,
#  'dGDP': 1,
#  'dGMP': 1,
#  'Deoxyguanosine': 1,
#  'dGTP': 1,
#  'glycerone': 1,
#  'Dihydroxyacetone phosphate': 1,
#  '7,8-Dihydrofolate': 1,
#  'dihydrolipoamide': 1,
#  'Dihydrolipolprotein': 1,
#  '1,4-Dihydroxy-2-naphthoate': 1,
#  '1,4-Dihydroxy-2-naphthoyl-CoA': 1,
#  'Dihydroneopterin': 1,
#  '(S)-dihydroorotate': 1,
#  'Dihydropteroate': 1,
#  'Deoxyinosine': 1,
#  '5,6-Dimethylbenzimidazole': 1,
#  '6,7-Dimethyl-8-(1-D-ribityl)lumazine': 1,
#  'Dimethylallyl diphosphate': 1,
#  'Deamino-NAD+': 1,
#  'DNA replication': 1,
#  'Dephospho-CoA': 1,
#  '2-deoxy-D-ribose': 2,
#  'dihydrosirohydrochlorin': 1,
#  'dTDP': 1,
#  'dTMP': 1,
#  'dTTP': 1,
#  'dUDP': 1,
#  'dUMP': 1,
#  'Deoxyuridine': 1,
#  'dUTP': 1,
#  '1-deoxy-D-xylulose 5-phosphate': 1,
#  'erythro-4-hydroxy-L-glutamate(1-)': 1,
#  'D-Erythrose 4-phosphate': 1,
#  'D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate': 1,
#  'Ethanolamine': 1,
#  'Ethanol': 1,
#  'D-Fructose 1-phosphate': 1,
#  'D-Fructose 6-phosphate': 1,
#  'Fatty acid (Iso-C17:0)': 1,
#  'Fatty acid (Anteiso-C17:0)': 1,
#  'Fatty acid (Iso-C14:0)': 1,
#  'Fatty acid (Iso-C15:0)': 1,
#  'Fatty acid (Anteiso-C15:0)': 1,
#  'Fatty acid (iso-C16:0)': 1,
#  'Flavin adenine dinucleotide oxidized': 1,
#  'Flavin adenine dinucleotide reduced': 1,
#  'D-Fructose 1,6-bisphosphate': 1,
#  'Oxidized ferredoxin': 1,
#  'Reduced ferredoxin': 1,
#  'Fe2+': 2,
#  'Fe3+': 2,
#  'N2-Formyl-N1-(5-phospho-D-ribosyl)glycinamide': 1,
#  'Ferricytochrome c': 1,
#  'FMN': 1,
#  'Reduced FMN': 1,
#  'Ferrocytochrome C': 1,
#  'Folate': 2,
#  'Formate': 1,
#  'N-Formimidoyl-L-glutamate': 1,
#  '2-(Formamido)-N1-(5-phospho-D-ribosyl)acetamidine': 1,
#  '5-Formamido-1-(5-phospho-D-ribosyl)imidazole-4-carboxamide': 1,
#  'Farnesyl diphosphate': 1,
#  'D-Fructose': 2,
#  'Fumarate': 1,
#  'D-Glucose 1-phosphate': 1,
#  'Glyceraldehyde 3-phosphate': 1,
#  'sn-Glycero-3-phosphocholine': 1,
#  'sn-Glycero-3-phosphoethanolamine': 1,
#  'Glycerophosphoglycerol': 1,
#  'D-Glucose 6-phosphate': 1,
#  'beta-D-glucose 6-phosphate': 1,
#  'D-galactopyranose 1-phosphate': 1,
#  'D-Galactose': 2,
#  'Galactitol 1-phosphate': 1,
#  'galactitol': 1,
#  'D-Glucosamine 1-phosphate': 1,
#  'D-Glucosamine 6-phosphate': 1,
#  'D-Glucosamine': 1,
#  'N1-(5-Phospho-D-ribosyl)glycinamide': 1,
#  'glycolaldehyde': 2,
#  'GDP': 1,
#  'GDP-alpha-D-mannose(2-)': 1,
#  'Guanosine 3-diphosphate 5-triphosphate': 1,
#  '2-trans,6-trans,10-trans-geranylgeranyl diphosphate(3-)': 1,
#  'D-glucose': 2,
#  'L-glutamine': 2,
#  'L-Glutamate 1-semialdehyde': 1,
#  'L-Glutamate 5-phosphate': 1,
#  'L-Glutamate 5-semialdehyde': 1,
#  'D-Glutamate': 2,
#  'L-glutamate': 2,
#  'L-Glutamyl-tRNA(Glu)': 1,
#  'glyoxylate': 1,
#  'Glycine': 2,
#  'D-Glyceraldehyde': 1,
#  'Glycyl-L-asparagine': 2,
#  'Glycyl-L-aspartate': 2,
#  'glycine betaine': 2,
#  'Glycerol 3-phosphate': 2,
#  'glycerol teichoic acid (n=45), linked, unsubstituted': 1,
#  'glycerol teichoic acid (n=45), linked, D-ala substituted': 1,
#  'glycerol teichoic acid (n=45), linked, glucose substituted': 1,
#  'Glycerol': 2,
#  'D-glycerate': 1,
#  'Gly-Cys': 2,
#  'Glycyl-L-glutamine': 2,
#  'Glycyl-L-glutamate': 2,
#  'Glycylleucine': 2,
#  'Glycyl-L-methionine': 2,
#  'Glycylphenylalanine': 2,
#  'Glycylproline': 2,
#  'Glycyl-L-tyrosine': 2,
#  'GMP': 1,
#  'Geranyl diphosphate': 1,
#  'Guanosine': 1,
#  'Reduced glutathione': 1,
#  'GTP': 1,
#  'Guanine': 1,
#  'Hydrogen': 1,
#  '1-hydroxy-2-methyl-2-(E)-butenyl 4-diphosphate': 1,
#  'Hydrogen peroxide': 1,
#  'Water': 2,
#  'Hydrogen sulfide': 1,
#  '3-hydroxy-L-kynurenine': 1,
#  'proton': 2,
#  'Bicarbonate': 1,
#  'L-homocysteine': 1,
#  'Hexadecanoate (n-C16:0)': 1,
#  'Hexadecenoate (n-C16:1)': 1,
#  'Hexadecenoyl-CoA (n-C16:1CoA)': 1,
#  'trans-Hexadec-2-enoyl-CoA': 1,
#  'cis-hexadec-9-enoyl-[acyl-carrier protein] (n-C16:1)': 1,
#  'Heme O': 1,
#  'all-trans-Heptaprenyl diphosphate': 1,
#  'Hydroxy ethyl Thiamin diphosphate': 1,
#  'Hexanoyl-ACP (n-C6:0ACP)': 1,
#  'all-trans-Hexaprenyl diphosphate': 1,
#  'Hg2+': 2,
#  'L-histidine': 1,
#  'L-Histidinol phosphate': 1,
#  'L-Histidinol': 1,
#  'L-Histidinal': 1,
#  'Hydroxymethylbilane': 1,
#  'L-homoserine': 1,
#  'Hypoxanthine': 2,
#  'Hexanoyl-CoA (n-C6:0CoA)': 1,
#  'Isotetradecanoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Isotetradecanoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  'Isopentadecanoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Isopentadecanoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  'Isohexadecanoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Isohexadecanoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  'Isoheptadecanoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Isoheptadecanoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  'isobutyryl-CoA(4-)': 1,
#  'Isochorismate': 1,
#  'Isocitrate': 1,
#  'IDP(3-)': 1,
#  'fa6coa,Iso-C16:0 CoA   Isohexadecanoyl-CoA': 1,
#  'fa11coa, Iso-C17:0 CoA   Isoheptadecanoyl-CoA': 1,
#  'L-isoleucine': 1,
#  'imidazol-4-ylacetate': 1,
#  'imidazole-4-acetaldehyde': 1,
#  '3-(Imidazol-4-yl)-2-oxopropyl phosphate': 1,
#  'Iminoglycine': 1,
#  'IMP': 1,
#  'indole-3-acetate': 1,
#  'Indole-3-acetamide': 1,
#  'Indole': 1,
#  'myo-inositol': 1,
#  'Inosine': 1,
#  'fa3coa,Iso-C15:0 CoA   Isopentadecanoyl-CoA': 1,
#  'Isopentenyl diphosphate': 1,
#  'fa1coa,Iso-C14:0 CoA   Isotetradecanoyl-CoA': 1,
#  'ITP(3-)': 1,
#  'Isovaleryl-CoA': 1,
#  'potassium': 2,
#  'L-2-Amino-6-oxopimelate': 1,
#  'L-lactate': 1,
#  'Lactulose': 1,
#  'L-leucine': 2,
#  'lipoate': 1,
#  'lipoamide': 1,
#  'Lipoylprotein': 1,
#  'L-lysine': 1,
#  'Malonyl-[acyl-carrier protein]': 1,
#  'L-malate': 1,
#  'Malonyl-CoA': 1,
#  'Maltose 6-phosphate': 1,
#  'Maltose': 2,
#  'Maltohexaose': 2,
#  'maltotriose': 2,
#  'D-Mannose 1-phosphate': 1,
#  'D-Mannose 6-phosphate': 1,
#  'D-Mannose': 2,
#  'mannotriose (beta-1,4)': 2,
#  'Melibiose': 1,
#  'L-methionine': 2,
#  'L-methionyl-L-alanine': 2,
#  '5,10-Methenyltetrahydrofolate': 1,
#  'L-Methionine Sulfoxide': 1,
#  'magnesium': 2,
#  '1D-myo-inositol 1-phosphate(2-)': 1,
#  '(2S,3R)-3-hydroxybutane-1,2,3-tricarboxylate': 1,
#  '5,10-Methylenetetrahydrofolate': 1,
#  'Mn2+': 2,
#  'D-Mannitol 1-phosphate': 1,
#  'D-Mannitol': 2,
#  'Menaquinol 8': 1,
#  'Menaquinone 8': 1,
#  'Myristoyl-ACP (n-C14:0ACP)': 1,
#  'Myristoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Myristoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  'Sodium': 2,
#  'Nicotinate': 1,
#  'Nicotinamide adenine dinucleotide': 1,
#  'Nicotinamide adenine dinucleotide - reduced': 1,
#  'Nicotinamide adenine dinucleotide phosphate': 1,
#  'Nicotinamide adenine dinucleotide phosphate - reduced': 1,
#  'Nicotinamide': 1,
#  'N-Carbamoylputrescine': 1,
#  'N-Formyl-L-glutamate': 1,
#  'Ammonium': 2,
#  'Nicotinate D-ribonucleoside': 1,
#  'Nicotinate D-ribonucleotide': 1,
#  'NMN': 2,
#  'O2': 2,
#  'superoxide': 1,
#  'Oxaloacetate': 1,
#  'trans-Oct-2-enoyl-CoA': 1,
#  'Octanoyl-ACP (n-C8:0ACP)': 1,
#  'Octanoyl-CoA (n-C8:0CoA)': 1,
#  'Octadecanoyl-ACP (n-C18:0ACP)': 1,
#  'octadecanoate (n-C18:0)': 2,
#  'octadecenoate (n-C18:1)': 1,
#  'all-trans-Octaprenyl diphosphate': 1,
#  'cis-octadec-11-enoyl-[acyl-carrier protein] (n-C18:1)': 1,
#  'Octadecenoyl-CoA (n-C18:1CoA)': 1,
#  '2-Oxo-3-hydroxy-4-phosphobutanoate': 1,
#  'Ornithine': 1,
#  'Orotidine 5-phosphate': 1,
#  'Orotate': 1,
#  'oxalate(2-)': 2,
#  '3-Oxoadipyl-CoA': 1,
#  '1,2-didodecanoyl-sn-glycerol 3-phosphate': 1,
#  '1,2-ditetradecanoyl-sn-glycerol 3-phosphate': 1,
#  '1,2-ditetradec-7-enoyl-sn-glycerol 3-phosphate': 1,
#  '1,2-dihexadecanoyl-sn-glycerol 3-phosphate': 1,
#  '1,2-dihexadec-9-enoyl-sn-glycerol 3-phosphate': 1,
#  '1,2-dioctadecanoyl-sn-glycerol 3-phosphate': 1,
#  '1,2-dioctadec-11-enoyl-sn-glycerol 3-phosphate': 1,
#  '1,2-dianteisopentadecanoyl-sn-glycerol 3-phosphate (12-methyl-tetradecanoyl, anteiso-C15)': 1,
#  '1,2-dianteisoheptadecanoyl-sn-glycerol 3-phosphate (14-methyl-hexadecanoyl, anteiso-C17)': 1,
#  'phenylacetate': 1,
#  '2-Phenylacetamide': 1,
#  '1,2-diisotetradecanoyl-sn-glycerol 3-phosphate (12-methyl-tridecanoyl, iso-C14)': 1,
#  '1,2-diisopentadecanoyl-sn-glycerol 3-phosphate (13-methyl-tetradecanoyl, iso-C15)': 1,
#  '1,2-diisohexadecanoyl-sn-glycerol 3-phosphate (14-methyl-pentadecanoyl, iso-C16)': 1,
#  '1,2-diisoheptadecanoyl-sn-glycerol 3-phosphate (15-methyl-hexadecanoyl, iso-C17)': 1,
#  'Palmitoyl-ACP (n-C16:0ACP)': 1,
#  'Palmitoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Palmitoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  'Pantetheine 4-phosphate': 1,
#  '(R)-Pantoate': 1,
#  'adenosine 3,5-bismonophosphate(4-)': 1,
#  'Lead': 2,
#  'phosphatidylethanolamine (dioctadecanoyl, n-C18:0)': 1,
#  'Phosphatidylethanolamine (14-methyl-hexadecanoyl, anteiso-C17)': 1,
#  'Phosphatidylethanolamine (15-methyl-hexadecanoyl, iso-C17)': 1,
#  'all-trans-Pentaprenyl diphosphate': 1,
#  'Phosphoenolpyruvate': 1,
#  'Peptide-L-methionine': 1,
#  'Peptide-L-methionine (R)-S-oxide': 1,
#  'Phosphatidylglycerol (dioctadecanoyl, n-C18:0)': 1,
#  'Phosphatidylglycerol (14-methyl-hexadecanoyl, anteiso-C17)': 1,
#  'Phosphatidylglycerol (15-methyl-hexadecanoyl, iso-C17)': 1,
#  'Phosphatidylglycerophosphate (didodecanoyl, n-C12:0)': 1,
#  'Phosphatidylglycerophosphate (ditetradecanoyl, n-C14:0)': 1,
#  'Phosphatidylglycerophosphate (ditetradec-7-enoyl, n-C14:1)': 1,
#  'Phosphatidylglycerophosphate (dihexadecanoyl, n-C16:0)': 1,
#  'Phosphatidylglycerophosphate (dihexadec-9-enoyl, n-C16:1)': 1,
#  'Phosphatidylglycerophosphate (dioctadecanoyl, n-C18:0)': 1,
#  'Phosphatidylglycerophosphate (dioctadec-11-enoyl, n-C18:1)': 1,
#  'Phosphatidylglycerophosphate (12-methyl-tetradecanoyl, anteiso-C15)': 1,
#  'Phosphatidylglycerophosphate (14-methyl-hexadecanoyl, anteiso-C17)': 1,
#  'Phosphatidylglycerophosphate (12-methyltridecanoyl, iso-C14)': 1,
#  'Phosphatidylglycerophosphate (13-methyltetradecanoyl, iso-C15)': 1,
#  'Phosphatidylglycerophosphate (14-methylpentadecanoyl, iso-C16)': 1,
#  'Phosphatidylglycerophosphate (15-methyl-hexadecanoyl, iso-C17)': 1,
#  'phenylacetyl-CoA(4-)': 1,
#  'L-phenylalanine': 1,
#  'Protoheme': 2,
#  'O-phosphonato-L-homoserine(2-)': 1,
#  'keto-phenylpyruvate': 1,
#  'O-Phospho-4-hydroxy-L-threonine': 1,
#  'Phytoene': 1,
#  'hydrogenphosphate': 2,
#  'Palmitoyl-CoA (n-C16:0CoA)': 1,
#  '4-Hydroxynitrobenzene, p-Nitrophenol': 1,
#  '(R)-Pantothenate': 1,
#  'Propionate': 1,
#  'Propanoyl phosphate': 1,
#  'Porphobilinogen': 1,
#  'Propanoyl-CoA': 1,
#  'Prephenate': 1,
#  'Prephytoene diphosphate': 1,
#  'Diphosphate': 2,
#  'Protoporphyrin': 1,
#  'Protoporphyrinogen IX': 1,
#  'triphosphate(5-)': 1,
#  '5-Phospho-beta-D-ribosylamine': 1,
#  'N-(5-Phospho-D-ribosyl)anthranilate': 1,
#  '1-(5-Phosphoribosyl)-AMP': 1,
#  '1-(5-Phosphoribosyl)-ATP': 1,
#  '1-(5-Phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino]imidazole-4-carboxamide': 1,
#  'Prenol-45n teichoic acid': 1,
#  'Prenol-45n teichoic acid-alanine substituted': 1,
#  'Prenol-45n teichoic acid-glucose substituted': 1,
#  '5-[(5-phospho-1-deoxyribulos-1-ylamino)methylideneamino]-1-(5-phosphoribosyl)imidazole-4-carboxamide': 1,
#  'L-proline': 2,
#  'Protein biosynthesis': 1,
#  'acryloyl-CoA(4-)': 1,
#  '5-Phospho-alpha-D-ribose 1-diphosphate': 1,
#  'phosphatidylserine (dioctadecanoyl, n-C18:0)': 1,
#  'Phosphatidylserine (14-methyl-hexadecanoyl, anteiso-C17)': 1,
#  'Pseudouridine 5-phosphate': 1,
#  'O-Phospho-L-serine': 1,
#  'Phosphatidylserine (15-methyl-hexadecanoyl, iso-C17)': 1,
#  'Putrescine': 1,
#  'Pyridoxal 5-phosphate': 1,
#  'Pyruvate': 1,
#  'Ubiquinone-8': 1,
#  'Ubiquinol-8': 1,
#  'alpha-D-Ribose 1-phosphate': 1,
#  'R406': 1,
#  'alpha-D-Ribose 5-phosphate': 1,
#  'R788 (Fostamatinib)': 1,
#  'Raffinose': 1,
#  'N1-(alpha-D-ribosyl)-5,6-dimethylbenzimidazole': 1,
#  'D-ribose': 2,
#  'Riboflavin': 2,
#  'N-Ribosylnicotinamide': 1,
#  'RNA transcription': 1,
#  'D-ribulose 5-phosphate(2-)': 1,
#  'Sedoheptulose 1,7-bisphosphate': 1,
#  'Sedoheptulose 7-phosphate': 1,
#  'Salicin 6-phosphate': 1,
#  'Salicin': 1,
#  'D-Sorbitol 6-phosphate': 1,
#  'D-glucitol': 2,
#  'O-Succinylbenzoyl-CoA': 1,
#  'sirohydrochlorin': 1,
#  'D-serine': 2,
#  'L-serine': 2,
#  'Siroheme': 1,
#  'Shikimate 5-phosphate': 1,
#  'Shikimate': 1,
#  'N-Succinyl-LL-2,6-diaminoheptanedioate': 1,
#  'N-Succinyl-2-L-amino-6-oxoheptanedioate': 1,
#  'Sulfite': 1,
#  'sulfate': 2,
#  'Spermidine': 2,
#  'Stearoyl-CoA (n-C18:0CoA)': 1,
#  'Stearoyllipoteichoic acid (n=24), linked, unsubstituted': 1,
#  'Stearoyllipoteichoic acid (n=24), linked, N-acetyl-D-glucosamine': 1,
#  'Stachyose': 1,
#  'Sucrose 6-phosphate': 1,
#  'o-Succinylbenzoate': 1,
#  'Succinate': 2,
#  'Succinyl-CoA': 1,
#  'O-Succinyl-L-homoserine': 1,
#  'Sucrose': 2,
#  'Succinic semialdehyde': 1,
#  'D-Tagatose 6-phosphate': 1,
#  'D-Tagatose 1,6-biphosphate': 1,
#  'minor teichoic acid (acetylgalactosamine glucose phosphate, n=30)': 1,
#  'trans-Tetradec-2-enoyl-CoA': 1,
#  'Tetradecanoyl-CoA (n-C14:0CoA)': 1,
#  'trans-Dodec-2-enoyl-[acyl-carrier protein]': 1,
#  'cis-tetradec-7-enoyl-[acyl-carrier protein] (n-C14:1)': 1,
#  'trans-Dec-2-enoyl-[acyl-carrier protein]': 1,
#  'teichuronic acid (GlcA + GalNac, 45 repeating unit)': 1,
#  '2,3,4,5-Tetrahydrodipicolinate': 1,
#  'trans-Hex-2-enoyl-[acyl-carrier protein]': 1,
#  '5,6,7,8-Tetrahydrofolate': 1,
#  'Tetrahydrofolyl-[Glu](2)': 1,
#  'Thiamin': 2,
#  'Thiamin monophosphate': 1,
#  'Thiamine diphosphate': 1,
#  'L-threonine': 1,
#  'Thymine': 1,
#  'Thymidine': 1,
#  'trans-Tetradec-2-enoyl-[acyl-carrier protein]': 1,
#  'trans-Oct-2-enoyl-[acyl-carrier protein]': 1,
#  'trans-octadec-2-enoyl-[acyl-carrier protein]': 1,
#  'trans-Hexadec-2-enoyl-[acyl-carrier protein]': 1,
#  'Oxidized thioredoxin': 1,
#  'Reduced thioredoxin': 1,
#  'alpha,alpha-Trehalose 6-phosphate': 1,
#  'Trehalose': 2,
#  'tRNA (Glu)': 1,
#  'L-tryptophan': 2,
#  'thiosulfate(2-)': 1,
#  'tetradecanoate (n-C14:0)': 2,
#  'D-Turanose': 2,
#  'L-tyrosine': 2,
#  'UDP-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-L-lysyl-D-alanyl-D-alanine': 1,
#  'Undecaprenyl-diphospho-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-L-lysyl-D-alanyl-D-alanine': 1,
#  'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutamyl-L-lysyl-D-alanyl-D-alanine': 1,
#  'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutaminyl-L-lysyl-D-alanyl-D-alanine': 1,
#  'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-D-alanyl-D-alanine': 1,
#  'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-isoglutaminyl-L-lysyl-D-alanyl-D-alanine': 1,
#  'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-ala-D-glu-meso-2,6-diaminopimeloyl-D-ala-D-ala': 1,
#  'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutaminyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine': 1,
#  'UDP-N-acetyl-3-O-(1-carboxyvinyl)-D-glucosamine': 1,
#  'UDP-N-acetyl-alpha-D-glucosamine(2-)': 1,
#  'UDP-N-acetyl-D-mannosamine': 1,
#  'UDP-N-acetyl-D-mannosaminouronate': 1,
#  'Undecaprenyl-diphospho-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine': 1,
#  'UDP-N-acetylmuramoyl-L-alanine': 1,
#  'UDP-N-acetylmuramoyl-L-alanyl-D-glutamate': 1,
#  'UDP-N-acetylmuramate': 1,
#  'Undecaprenyl diphosphate': 1,
#  'Undecaprenyl phosphate': 1,
#  'UDP': 1,
#  'UDP-N-acetyl-D-galactosamine(2-)': 1,
#  'UDPglucose': 1,
#  'UDP-D-galactose(2-)': 1,
#  'UDP-D-galacto-1,4-furanose': 1,
#  'UDP-D-glucuronate': 1,
#  'UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate': 1,
#  'UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine': 1,
#  'UMP': 1,
#  'Undecaprenyl diphospho N-acetyl-glucosamine': 1,
#  'Uroporphyrinogen III': 1,
#  'uracil': 2,
#  'Urocanate': 1,
#  'Uridine': 1,
#  'UTP': 1,
#  'L-valine': 1,
#  'Xanthine': 1,
#  'Xanthosine 5-phosphate': 1,
#  'xanthosine': 1,
#  'D-xylulose 5-phosphate(2-)': 1,
#  'D-xylulose': 1,
#  'Zinc': 2}

# %%
# filt_f = [val for val in formyl_tups if val[2][0]=='CHEBI:1']
# filt_f

# %%
# for idx, one_trip in enumerate(value_trips):
#   if idx>200:
#     break
#   print("%s : %s" % (one_trip[0], one_trip[1]))
#   print(one_trip[2])

# %%
# print(model.getSpecies('M_13dpg__91__c__93__').getAnnotationString())

# %%
recom.recommendSpecies(ids='M_12ppd_S__91__c__93__')
# Out:
#                                    file     type                      id  \
# 0  Abiotrophia_defectiva_ATCC_49176.xml  species  M_12ppd_S__91__c__93__
#
#            display name                 meta id   annotation  \
# 0  (S)-propane-1,2-diol  M_12ppd_S__91__c__93__  CHEBI:29002
#
#        annotation label  match score  existing UPDATE ANNOTATION
# 0  (S)-propane-1,2-diol          1.0         0            ignore

# %%
bigg_all_species[3]
# Out:
# 'S-Adenosylmethioninamine'

# %%
# value_triples
one_k = bigg_all_species[3]

val_triples = []

for idx, one_bigg in enumerate(biggs):
  if idx % 10 == 0:
    print("We're at", idx)
  one_fpath = os.path.join(BIGG_DIR, one_bigg)
  recom = recommender.Recommender(libsbml_fpath=one_fpath)
  model = recom.sbml_document.getModel()  
  for val in model.getListOfSpecies():
    if val.getId() in recom.species.exist_annotation.keys():
      val_triples.append((one_bigg,
                          val.getId(),
                          one_k,
                          recom.species.exist_annotation[val.getId()]))
# Out:
# We're at 0
# We're at 10
# We're at 20
# We're at 30
# We're at 40
# We're at 50
# We're at 60
# We're at 70
# We're at 80
# We're at 90
# We're at 100

# %%
# summary of biggs
biggs = [val for val in os.listdir(BIGG_DIR) if val[-3:]=='xml']

kins = dict()
all_spec_names = []

for idx, one_bigg in enumerate(biggs):
  if idx % 10 == 0:
    print("We're at", idx)
  one_fpath = os.path.join(BIGG_DIR, one_bigg)
  recom = recommender.Recommender(libsbml_fpath=one_fpath)
  model = recom.sbml_document.getModel() 
  all_spec_names.append([recom.species.getNameToUse(val.getId()) \
                         for val in model.getListOfSpecies()])
  # checking kinetics
  one_set_kins = dict()
  for one_r in model.getListOfReactions():
    one_k = one_r.getKineticLaw()
    if one_k:
      one_set_kins[one_r.getId()] = one_k
  kins[one_bigg] = one_set_kins
# Out:
# We're at 0
# We're at 10
# We're at 20
# We're at 30
# We're at 40
# We're at 50
# We're at 60
# We're at 70
# We're at 80
# We're at 90
# We're at 100

# %%
len(cn.REF_CHEBI2LABEL)
# Out:
# 159840

# %%
recom.species.getNameToUse('M_nadph_c')
# Out:
# 'Nicotinamide adenine dinucleotide phosphate - reduced'

# %%
recom.species.getNameToUse('M_coa_c')
# Out:
# 'Coenzyme A'

# %%
from collections import Counter
spec_names_with_rep = itertools.chain(*all_spec_names)
count_specs = dict(Counter(spec_names_with_rep))

# %%
one_name = list(count_specs.keys())[4]
res_models = dict()
spec_anots = []
for idx, one_bigg in enumerate(biggs):
  if idx % 10 == 0:
    print("We're at", idx)
  one_fpath = os.path.join(BIGG_DIR, one_bigg)
  recom = recommender.Recommender(libsbml_fpath=one_fpath)
  model = recom.sbml_document.getModel() 
  spec_names = [val.getId() for val in model.getListOfSpecies() \
               if recom.species.getNameToUse(val.getId())==one_name]
  if spec_names:
    for one_spec in spec_names:
      spec_anots.append(model.getSpecies(one_spec).getAnnotationString())
  if len(spec_anots)>=100:
    break
# Out:
# We're at 0
# We're at 10
# We're at 20
# We're at 30
# We're at 40
# We're at 50
# We're at 60
# We're at 70

# %%
for one_a in spec_anots:
  print(one_a)
  print()
# Out:
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_e">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_l">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_m">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_e">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_l">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_m">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_h">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
# ...
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_h">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>
#
# <sbml:annotation xmlns:sbml="http://www.sbml.org/sbml/level3/version1/core">
#   <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#     <rdf:Description rdf:about="#M_10fthf_c">
#       <bqbiol:is xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#         <rdf:Bag>
#           <rdf:li rdf:resource="http://identifiers.org/bigg.metabolite/10fthf"/>
#           <rdf:li rdf:resource="http://identifiers.org/biocyc/META:10-FORMYL-THF"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19108"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:15637"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:698"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:19109"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:11304"/>
#           <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:57454"/>
#           <rdf:li rdf:resource="http://identifiers.org/hmdb/HMDB00972"/>
#           <rdf:li rdf:resource="http://identifiers.org/inchi_key/AUFGTPPARQZWDO-YPMHNXCESA-L"/>
#           <rdf:li rdf:resource="http://identifiers.org/kegg.compound/C00234"/>
#           <rdf:li rdf:resource="http://identifiers.org/metanetx.chemical/MNXM237"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/5389850"/>
#           <rdf:li rdf:resource="http://identifiers.org/reactome.compound/419151"/>
#           <rdf:li rdf:resource="http://identifiers.org/sabiork/1318"/>
#           <rdf:li rdf:resource="http://identifiers.org/seed.compound/cpd00201"/>
#         </rdf:Bag>
#       </bqbiol:is>
#     </rdf:Description>
#   </rdf:RDF>
# </sbml:annotation>

# %%
# check if there are same named species with different annotations; 
spec_names_ll = []
[recom.species.getNameToUse(val.getId()) for val in model.getListOfSpecies()]
# Out:
# ['Protoheme C34H30FeN4O4',
#  'Molybdate',
#  'Phosphatidylethanolamine (dioctadec-11-enoyl, n-C18:1)',
#  'Coenzyme A',
#  'Phosphatidylglycerol (dihexadec-9-enoyl, n-C16:1)',
#  'Nicotinamide adenine dinucleotide phosphate - reduced',
#  'Nickel',
#  'H+',
#  'Nicotinamide adenine dinucleotide phosphate',
#  'L-Glutamine',
#  'Molybdopterin cytosine dinucleotide',
#  '5-Methyltetrahydrofolate',
#  'Undecaprenyl diphosphate',
#  'Acetyl-CoA',
#  'Malonyl CoA C24H33N7O19P3S',
#  'Core oligosaccharide lipid A',
#  'L-Tryptophan',
#  'P-Cresol',
#  'Butyrate (n-C4:0)',
#  'Butanesulfonate',
#  "5'-deoxyribose",
#  'DCTP C9H12N3O13P3',
#  'Calcium',
#  'Phosphatidylglycerol (dihexadecanoyl, n-C16:0)',
#  'Cobinamide',
#  'Aminoacetaldehyde',
#  'Reduced glutathione',
#  'S-Adenosyl-4-methylthio-2-oxobutanoate',
#  'Cob(I)alamin',
#  'Cadmium',
#  'Thiamine diphosphate',
#  'Cys Gly C5H10N2O3S',
#  'Nicotinamide adenine dinucleotide - reduced',
#  'Choline C5H14NO',
#  '(2R,4S)-2-methyl-2,3,3,4-tetrahydroxytetrahydrofuran',
#  'GTP C10H12N5O14P3',
#  'Zinc',
#  "N,N'-diacetylchitobiose",
#  'Flavin adenine dinucleotide oxidized',
#  'Citrate',
#  'Chloride',
#  'Oxamate',
#  '5,10-Methylenetetrahydrofolate',
#  'Ubiquinol-8',
#  'Chloramphenicol',
#  'L-Threonine',
#  'CMP C9H12N3O8P',
#  'L-Leucine',
#  'CO2 CO2',
#  'Two disacharide linked murein units, pentapeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain)',
#  'Co2+',
#  '2-Octaprenyl-6-hydroxyphenol',
#  'Core oligosaccharide lipid A diphosphate',
#  'Coprogen',
#  'Two disacharide linked murein units, tripeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain)',
#  'KDO(2)-lipid IV(A)',
#  '5,6,7,8-Tetrahydrofolate',
#  'Coprogen unloaded (no Fe(III))',
#  'L-Carnitine',
#  '(R)-Propane-1,2-diol',
#  'D-Carnitine',
#  'DATP C10H12N5O12P3',
#  '(S)-Propane-1,2-diol',
#  'Cytosine',
#  '1,4-alpha-D-glucan',
#  'Cu+',
#  'H2O H2O',
#  '1,5-Diaminopentane',
#  'L-Phenylalanine',
#  'Copper',
#  "2',3'-Cyclic AMP",
#  'Hydrogen cyanide',
#  'ADP C10H12N5O10P2',
#  "2',3'-Cyclic CMP",
#  'Cyanate',
#  "2',3'-Cyclic GMP",
#  'D-Cysteine',
#  'L-Cysteine',
#  '2-Demethylmenaquinol 8',
#  'Adenosylcobalamin',
#  "2',3'-Cyclic UMP",
#  'Cytidine',
#  'Biotin',
#  '2,3-diaminopropionate',
#  'Deoxyadenosine',
#  'Meso-2,6-Diaminoheptanedioate',
#  'DAMP C10H12N5O6P',
#  'Decanoate (n-C10:0)',
#  'UTP C9H11N2O15P3',
#  '2-Dehydro-3-deoxy-D-gluconate',
#  'Copper',
#  'DCMP C9H12N3O7P',
#  'Chorismate',
#  '3,4-Dihydroxyphenylacetaldehyde',
#  'Heme O C49H56FeN4O5',
#  'Deoxycytidine',
#  '3  AMP C10H12N5O7P',
#  'Dodecanoate (n-C12:0)',
#  'Phosphatidylethanolamine (dihexadec-9enoyl, n-C16:1)',
#  '3  CMP C9H12N3O8P',
#  'Two linked disacharide tripeptide murein units (uncrosslinked, middle of chain)',
#  'DGMP C10H12N5O7P',
#  'CTP C9H12N3O14P3',
#  'Guanosine 3  phosphate C10H12N5O8P',
#  'Manganese',
#  'Magnesium',
#  'Two disacharide linked murein units, tetrapeptide corsslinked tetrapeptide (A2pm->D-ala) (middle of chain)',
#  'Deoxyguanosine',
#  'Dihydroxyacetone',
#  'DIMP C10H12N4O7P',
#  'Deoxyinosine',
#  'Dimethyl sulfide',
#  '3-hydroxycinnamic acid',
#  'Dimethyl sulfoxide',
#  'Dopamine',
#  '10-Formyltetrahydrofolate',
#  'Bis-molybdopterin guanine dinucleotide',
#  '3-Hydroxypropanoate',
#  'L-Cysteine',
#  'Doxorubicin',
#  '3-(3-hydroxy-phenyl)propionate',
#  'DTMP C10H13N2O8P',
#  'Phosphatidylethanolamine (dioctadec-11-enoyl, n-C18:1)',
#  'DUMP C9H11N2O8P',
#  '3  UMP C9H11N2O9P',
#  'Deoxyuridine',
#  'Spermidine',
#  'Phosphatidylglycerol (dihexadec-9-enoyl, n-C16:1)',
#  '4-Aminobutanoate',
#  'Phosphatidylglycerol (dioctadec-11-enoyl, n-C18:1)',
#  '(enterobacterial common antigen)x4 core oligosaccharide lipid A',
#  '4-Hydroxyphenylacetaldehyde',
#  'Phosphoethanolamine KDO(2)-lipid (A)',
#  'DGTP C10H12N5O13P3',
#  'Enterochelin',
#  '5-Dehydro-D-gluconate',
#  'Ethanolamine',
#  '[4Fe-4S] iron-sulfur cluster',
#  '5-Methylthio-D-ribose',
#  'ATP C10H12N5O13P3',
#  'Ethanesulfonate',
#  'Ethanol',
#  "Pyridoxal 5'-phosphate",
#  'L-alanine-D-glutamate',
#  'Riboflavin C17H20N4O6',
#  'D-Fructose 6-phosphate',
#  'L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate',
#  'Formaldehyde',
#  'Enterochelin',
#  'L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine',
#  'L-Isoleucine',
#  'Fe2+ mitochondria',
#  'Iron (Fe3+)',
#  'L-alanine-L-glutamate',
#  'Fe(III)dicitrate',
#  'Co2+',
#  'Acetate',
#  'Fe2+ mitochondria',
#  'Ferric 2,3-dihydroxybenzoylserine',
#  'Acetoacetate',
#  'Fe(III)hydroxamate',
#  'L-Alanine',
#  'Acetaldehyde',
#  'Glycogen C6H10O5',
#  'Fe(III)hydoxamate, unloaded',
#  'N-Acetyl-D-galactosamine',
#  'Ferrichrome',
#  'Ferrichrome minus Fe(III)',
#  'L-Asparagine',
#  'N-Acetyl-D-galactosamine 1-phosphate',
#  'Chloride',
#  'Fe-enterobactin',
#  'N-Acetyl-D-glucosamine',
#  'Generic ferrioxamine-Fe-III',
#  'L-Valine',
#  'Molybdopterin guanine dinucleotide',
#  'N-Acetyl-D-glucosamine 1-phosphate',
#  'Ferroxamine minus Fe(3)',
#  'Formate',
#  'N-Acetyl-D-mannosamine',
#  'D-Fructose',
#  'Cardiolipin (tetraoctadec-11-enoyl, n-C18:1)',
#  'N-Acetylmuramate',
#  'Putrescine',
#  'Fructoselysine',
#  'N-Acetylneuraminate',
#  'D-Fructuronate',
#  'L-Lysine',
#  '4-Amino-4-deoxy-L-arabinose modified core oligosaccharide lipid A',
#  'Phosphatidylethanolamine (dihexadecanoyl, n-C16:0)',
#  'L-Fucose',
#  'O-Acetyl-L-serine',
#  'Fumarate',
#  'Lipoate (protein bound)',
#  'Phosphatidylethanolamine (dihexadecanoyl, n-C16:0)',
#  'Adenine',
#  'Phosphatidylglycerol (dihexadecanoyl, n-C16:0)',
#  'Fusidic acid',
#  'D-Glucose 1-phosphate',
#  'Adenosine',
#  'Sn-Glycero-3-phosphocholine',
#  'L-Tyrosine',
#  'Adenosylcobalamin',
#  'L-Methionine',
#  'Sn-Glycero-3-phosphoethanolamine',
#  'Silver',
#  'Glycerophosphoglycerol',
#  'L-Arginine',
#  'Agmatine',
#  'Phosphatidylglycerol (dioctadec-11-enoyl, n-C18:1)',
#  'Sn-Glycero-3-phospho-1-inositol',
#  'Glycerophosphoserine',
#  'D-Glucose 6-phosphate',
#  'Nicotinamide adenine dinucleotide',
#  'Sulfate',
#  '2-Oxoglutarate',
#  'Diphosphate',
#  'D-Galactose',
#  'Beta-Alanine',
#  'Beta D-Galactose',
#  'Glycine',
#  'D-Alanine',
#  'L-Serine',
#  'Alpha-D-Galactose 1-phosphate',
#  'L-Alanine',
#  'D-Galactarate',
#  'L-Aspartate',
#  'S-Adenosyl-L-methionine',
#  'D-Alanyl-D-alanine',
#  'Three disacharide linked murein units (tetrapeptide crosslinked tetrapeptide (A2pm->D-ala) & tetrapeptide corsslinked tetrapeptide (A2pm->D-ala)) (middle of chain)',
#  'D-Galactonate',
#  'D-Allose',
#  'L-Galactonate',
#  'Galactitol',
#  'L-Proline',
#  'Siroheme C42H36FeN4O16',
#  'Allantoin',
#  'Two linked disacharide tetrapeptide murein units (uncrosslinked, middle of chain)',
#  'D-Galacturonate',
#  'AMP C10H12N5O7P',
#  'D-Glucosamine',
#  'D-Glucosamine 6-phosphate',
#  'Phosphate',
#  'N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid',
#  'Calcium',
#  'Potassium',
#  'Gamma-butyrobetaine',
#  'L-Arabinose',
#  'GDP C10H12N5O11P2',
#  'L-Histidine',
#  'D-Glucose',
#  'Arbutin C12H16O7',
#  'Cardiolipin (tetrahexadecanoyl, n-C16:0)',
#  'Aerobactin minus Fe3',
#  'Succinyl-CoA',
#  'Aerobactin',
#  'Menaquinol 8',
#  'Iron (Fe3+)',
#  'D-Gluconate',
#  'D-Glucarate',
#  'L-Arginine',
#  'D-Glucuronate',
#  'Ammonium',
#  'L-Ascorbate',
#  '[2Fe-2S] iron-sulfur cluster',
#  'D-Glucuronate 1-phosphate',
#  'L-Asparagine',
#  'L-Glutamine',
#  'Cardiolipin (tetrahexadec-9-enoyl, n-C16:1)',
#  'Arsenite',
#  'Phosphatidylethanolamine (dihexadec-9enoyl, n-C16:1)',
#  'L-Glutamate',
#  'L-Glutamate',
#  'Glycine',
#  'L-Aspartate',
#  'D-Glyceraldehyde',
#  'DTTP C10H13N2O14P3',
#  'Biotin',
#  'Glycine betaine',
#  '1,4-alpha-D-glucan',
#  'Glycerol',
#  '(R)-Glycerate',
#  'Glycerol 2-phosphate',
#  'Glycerol 3-phosphate',
#  'Glycolate C2H3O3',
#  'GMP C10H12N5O8P',
#  'Guanosine',
#  'Oxidized glutathione',
#  'Reduced glutathione',
#  'GTP C10H12N5O14P3',
#  'Guanine',
#  'H+',
#  'Hydrogen',
#  'Phenylacetaldehyde',
#  'Phenethylamine',
#  'L-Phenylalanine',
#  'Protoheme C34H30FeN4O4',
#  'Phosphate',
#  '(R)-Pantothenate',
#  'Propionate (n-C3:0)',
#  'H2O H2O',
#  '1,4-alpha-D-glucan',
#  'Hydrogen peroxide',
#  'Hydrogen sulfide',
#  'Hepta-acylated core oligosaccharide lipid A (E. coli)',
#  'Propanal',
#  'Phenylpropanoate',
#  'Phosphonate',
#  'L-Proline',
#  'Hepta-acylated KDO(2)-lipid (A)',
#  "2',3'-Cyclic AMP",
#  'Hexadecanoate (n-C16:0)',
#  'L-Prolinylglycine',
#  'Psicoselysine',
#  'Hexadecenoate (n-C16:1)',
#  "2',3'-Cyclic CMP",
#  'Mercury  charged 2  Hg',
#  'O-Phospho-L-serine',
#  "2',3'-Cyclic GMP",
#  'Putrescine',
#  'Pyridoxamine',
#  'L-Histidine',
#  'L-Homoserine',
#  "2',3'-Cyclic UMP",
#  'Hexanoate (n-C6:0)',
#  'Hypoxanthine',
#  'Pyridoxal',
#  'Pyridoxine',
#  'Pyruvate',
#  'L-Idonate',
#  'H+',
#  'L-Isoleucine',
#  'IMP C10H11N4O8P',
#  'Quinate',
#  'Alpha-D-Ribose 5-phosphate',
#  '2,3-diaminopropionate',
#  'Rifampin',
#  'D-Ribose',
#  'Indole',
#  '2,3-diaminopropionate',
#  'Myo-Inositol',
#  'L-Rhamnose',
#  'Inosine',
#  'H2O H2O',
#  'Isethionic acid',
#  'D-Sorbitol',
#  'Selenate',
#  '3  UMP C9H11N2O9P',
#  'D-Serine',
#  'Potassium',
#  'L-Serine',
#  '3  CMP C9H12N3O8P',
#  'Shikimate',
#  'D-Lactate',
#  'L-Lactate',
#  'Selenite',
#  '3  AMP C10H12N5O7P',
#  'Sulfur dioxide',
#  'Lactose C12H22O11',
#  'Guanosine 3  phosphate C10H12N5O8P',
#  'L-Leucine',
#  'KDO(2)-lipid (A)',
#  'Sulfite',
#  'Sulfate',
#  'Meso-2,6-Diaminoheptanedioate',
#  'Spermidine',
#  'Cold adapted KDO(2)-lipid (A)',
#  'Lipoate',
#  '2-dodecanoyl-sn-glycerol 3-phosphate',
#  'L-Lysine',
#  'Succinate',
#  'Sucrose C12H22O11',
#  '2-dodecanoyl-sn-glycerol 3-phosphate',
#  'Sulfoacetate',
#  'L-Lyxose',
#  '2-tetradecanoyl-sn-glycerol 3-phosphate',
#  'D-Malate',
#  'D-tartrate',
#  'L-Malate',
#  '2-tetradecanoyl-sn-glycerol 3-phosphate',
#  'Maltose C12H22O11',
#  'L-tartrate',
#  '2-tetradec-7-enoyl-sn-glycerol 3-phosphate',
#  'Taurine C2H7NO3S',
#  'Thiocyanate',
#  'Maltohexaose',
#  'Maltopentaose',
#  '2-tetradec-7-enoyl-sn-glycerol 3-phosphate',
#  'Thiamin',
#  'Maltotriose C18H32O16',
#  '2-hexadecanoyl-sn-glycerol 3-phosphate',
#  'Maltotetraose',
#  'L-Threonine',
#  '2-hexadecanoyl-sn-glycerol 3-phosphate',
#  'L-Threonine O-3-phosphate',
#  'D-Mannose',
#  'Thymine C5H6N2O2',
#  '2-hexadec-9-enoyl-sn-glycerol 3-phosphate',
#  'Thymidine C10H14N2O5',
#  'D-Mannose 6-phosphate',
#  '2(alpha-D-Mannosyl)-D-glycerate',
#  '2-hexadec-9-enoyl-sn-glycerol 3-phosphate',
#  'Melibiose C12H22O11',
#  'Trimethylamine',
#  '2-octadecanoyl-sn-glycerol 3-phosphate',
#  'Trimethylamine N-oxide',
#  'Methanol',
#  '2-octadecanoyl-sn-glycerol 3-phosphate',
#  'D-Methionine',
#  'Trehalose',
#  'L-Tryptophan',
#  '2-octadec-11-enoyl-sn-glycerol 3-phosphate',
#  'Thiosulfate',
#  'L-Methionine',
#  'L-methionine-R-sulfoxide',
#  '2-octadec-11-enoyl-sn-glycerol 3-phosphate',
#  'L-Methionine Sulfoxide',
#  'Tetradecanoate (n-C14:0)',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C12:0)',
#  'Tetradecenoate (n-C14:1)',
#  'Tetracycline',
#  'Magnesium',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C12:0)',
#  'Minocycline',
#  'Myo-Inositol hexakisphosphate',
#  'Tungstate',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:0)',
#  'Tyramine',
#  'S-Methyl-L-methionine',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:0)',
#  'Manganese',
#  'L-Tyrosine',
#  'Phosphotyrosine',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1)',
#  'UDP-N-acetyl-D-glucosamine',
#  'UDP-N-acetyl-D-galactosamine',
#  'D-Mannitol',
#  'Molybdate',
#  'Methanesulfonate',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1)',
#  'Nitrous oxide',
#  'Sodium',
#  'UDPglucose',
#  'UDPgalactose',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0)',
#  'UDP-D-glucuronate',
#  'Nicotinate',
#  'UMP C9H11N2O9P',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0)',
#  'Uracil',
#  'Ammonium',
#  'Nickel',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:1)',
#  'NMN C11H14N2O8P',
#  'Urea CH4N2O',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:1)',
#  'Uridine',
#  'L-Valine',
#  'Nitric oxide',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:0)',
#  'Nitrite',
#  'Xanthine',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:0)',
#  "Xanthosine 5'-phosphate",
#  'Nitrate',
#  'Novobiocin',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:1)',
#  '(O16 antigen)x4 core oligosaccharide lipid A',
#  'Xanthosine',
#  '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:1)',
#  'D-Xylose',
#  'L-Xylulose',
#  'O2 O2',
#  'AMP C10H12N5O7P',
#  'Superoxide anion',
#  'Octadecanoate (n-C18:0)',
#  'Zinc',
#  'Phosphatidylethanolamine (didodecanoyl, n-C12:0)',
#  '1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)',
#  '1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)',
#  'Octadecenoate (n-C18:1)',
#  'Dodecanoate (n-C12:0)',
#  'Octanoate (n-C8:0)',
#  '1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)',
#  'Tetradecanoate (n-C14:0)',
#  '1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)',
#  '1,2-Diacyl-sn-glycerol (ditetradec-7-enoyl, n-C14:1)',
#  'Ornithine',
#  'Orotate C5H3N2O4',
#  'Phosphatidylethanolamine (ditetradecanoyl, n-C14:0)',
#  '1,2-Diacyl-sn-glycerol (ditetradec-7-enoyl, n-C14:1)',
#  '1,2-Diacyl-sn-glycerol (dihexadecanoyl, n-C16:0)',
#  'Phosphatidylethanolamine (ditetradec-7-enoyl, n-C14:1)',
#  '1,2-Diacyl-sn-glycerol (dihexadecanoyl, n-C16:0)',
#  'Tetradecenoate (n-C14:1)',
#  '1,2-Diacyl-sn-glycerol (dihexadec-9-enoyl, n-C16:1)',
#  '(R)-3-hydroxy-cis-palm-9-eoyl-[acyl-carrier protein]',
#  'Hexadecanoate (n-C16:0)',
#  '1,2-Diacyl-sn-glycerol (dihexadec-9-enoyl, n-C16:1)',
#  'Hexadecenoate (n-C16:1)',
#  '1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#  'Trans-3-cis-9-palmitoleoyl-[acyl-carrier protein]',
#  '1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)',
#  '(R)-3-Hydroxyoctadecanoyl-[acyl-carrier protein]',
#  'Phosphatidylethanolamine (dioctadecanoyl, n-C18:0)',
#  '1,2-Diacyl-sn-glycerol (dioctadec-11-enoyl, n-C18:1)',
#  'Octadecanoate (n-C18:0)',
#  '1,2-Diacyl-sn-glycerol (dioctadec-11-enoyl, n-C18:1)',
#  'Trans-octadec-2-enoyl-[acyl-carrier protein]',
#  'Trans-3-cis-11-vacceoyl-[acyl-carrier protein]',
#  '(R)-Propane-1,2-diol',
#  'Octadecenoate (n-C18:1)',
#  '(R)-Propane-1,2-diol',
#  '(R)-3-hydroxy-cis-vacc-11-enoyl-[acyl-carrier protein]',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0)',
#  'But-2-enoyl-[acyl-carrier protein]',
#  '(S)-Propane-1,2-diol',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0)',
#  '(S)-Propane-1,2-diol',
#  '(3R)-3-Hydroxyacyl-[acyl-carrier protein]',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0)',
#  '(R)-3-Hydroxyhexanoyl-[acyl-carrier protein]',
#  'Trans-Hex-2-enoyl-[acyl-carrier protein]',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0)',
#  '(R)-3-Hydroxyoctanoyl-[acyl-carrier protein]',
#  '2-Oxoglutarate',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:1)',
#  '4-Aminobutanal',
#  'Trans-Oct-2-enoyl-[acyl-carrier protein]',
#  'O2 O2',
#  '4-Aminobutanoate',
#  'Acetoacetyl-CoA',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:1)',
#  '3-Oxohexanoyl-CoA',
#  '3-hydroxycinnamic acid',
#  '2,3-dihydroxicinnamic acid',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0)',
#  '3-(2,3-Dihydroxyphenyl)propanoate',
#  'Butanoyl-CoA',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0)',
#  '3-Oxooctanoyl-CoA',
#  '3-(3-hydroxy-phenyl)propionate',
#  'Hexanoyl-CoA (n-C6:0CoA)',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1)',
#  'Octanoyl-CoA (n-C8:0CoA)',
#  '3-Hydroxypropanoate',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1)',
#  '3-Hydroxypropanoate',
#  '3-Oxodecanoyl-CoA',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0)',
#  'Decanoyl-CoA (n-C10:0CoA)',
#  '3-Dehydro-L-gulonate',
#  '3-keto-L-gulonate-6-phosphate',
#  '3-Oxododecanoyl-CoA',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0)',
#  '3-Oxotetradecanoyl-CoA',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1)',
#  'Dodecanoyl-CoA (n-C12:0CoA)',
#  'Phosphate',
#  '2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1)',
#  '3-Oxohexadecanoyl-CoA',
#  'Phosphatidylglycerol (didodecanoyl, n-C12:0)',
#  'Tetradecanoyl-CoA (n-C14:0CoA)',
#  'Palmitoyl-CoA (n-C16:0CoA)',
#  'Uridine',
#  'Phosphatidylglycerol (ditetradecanoyl, n-C14:0)',
#  'Cytidine',
#  '3-Oxooctadecanoyl-CoA',
#  'Phosphatidylglycerol (ditetradec-7-enoyl, n-C14:1)',
#  'Acetoacetate',
#  'Adenosine',
#  'Phosphatidylglycerol (dioctadecanoyl, n-C18:0)',
#  'Acetaldehyde',
#  '2-Dehydro-L-gulonate',
#  'Acetaldehyde',
#  'Guanosine',
#  'N-Acetylanthranilate',
#  'D-Gluconate',
#  'Anthranilate',
#  '3-Oxodecanoyl-[acyl-carrier protein]',
#  '3-Oxododecanoyl-[acyl-carrier protein]',
#  'L-Idonate',
#  '3-oxo-cis-dodec-5-enoyl-[acyl-carrier protein]',
#  'Adenosyl cobinamide phosphate',
#  '4-Amino-2-methyl-5-phosphomethylpyrimidine',
#  'Adenosine-GDP-cobinamide',
#  'Bicarbonate',
#  '3-Oxotetradecanoyl-[acyl-carrier protein]',
#  '3-oxo-cis-myristol-7-eoyl-[acyl-carrier protein]',
#  '2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphate',
#  '3-Oxohexadecanoyl-[acyl-carrier protein]',
#  'Propanoyl-CoA',
#  '3,4-Dihydroxyphenylacetaldehyde',
#  'Propionate (n-C3:0)',
#  '3-oxo-cis-palm-9-eoyl-[acyl-carrier protein]',
#  '3-Oxooctadecanoyl-[acyl-carrier protein]',
#  'N-Acetyl-D-galactosamine',
#  '3-Aminoacrylate',
#  'N-Acetyl-D-galactosamine 1-phosphate',
#  '3-oxo-cis-vacc-11-enoyl-[acyl-carrier protein]',
#  'Malonate semialdehyde',
#  'Acetoacetyl-ACP',
#  'N-Acetyl-D-glucosamine',
#  'Trans-Dec-2-enoyl-[acyl-carrier protein]',
#  'N-Acetyl-D-glucosamine 1-phosphate',
#  'N-Acetyl-D-glucosamine',
#  '3-Oxohexanoyl-[acyl-carrier protein]',
#  '(R)-3-Hydroxydecanoyl-[acyl-carrier protein]',
#  '3-Oxooctanoyl-[acyl-carrier protein]',
#  'CO2 CO2',
#  'N-Acetyl-D-glucosamine 6-phosphate',
#  'Undecaprenyl phosphate',
#  '(R)-3-Hydroxydodecanoyl-[acyl-carrier protein]',
#  'UMP C9H11N2O9P',
#  'Acyl carrier protein',
#  'Trans-Dodec-2-enoyl-[acyl-carrier protein]',
#  'Octanoyl-ACP (n-C8:0ACP)',
#  'Undecaprenyl diphospho N-acetyl-glucosamine',
#  '(R)-3-hydroxy-cis-dodec-5-enoyl-[acyl-carrier protein]',
#  'UDP-N-acetyl-D-glucosamine',
#  'Pyruvate',
#  'Malonyl-[acyl-carrier protein]',
#  'Decanoyl-ACP (n-C10:0ACP)',
#  'Trans-3-cis-5-dodecenoyl-[acyl-carrier protein]',
#  'Cis-dec-3-enoyl-[acyl-carrier protein] (n-C10:1)',
#  'Dodecanoyl-ACP (n-C12:0ACP)',
#  'Phosphoenolpyruvate',
#  'N-Acetyl-L-glutamyl 5-phosphate',
#  'N-Acetyl-L-glutamate',
#  'Cis-dodec-5-enoyl-[acyl-carrier protein] (n-C12:1)',
#  '(R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]',
#  'Myristoyl-ACP (n-C14:0ACP)',
#  '2-Oxobutanoate',
#  'Trans-Tetradec-2-enoyl-[acyl-carrier protein]',
#  '(S)-2-Aceto-2-hydroxybutanoate',
#  'Cis-tetradec-7-enoyl-[acyl-carrier protein] (n-C14:1)',
#  '(R)-3-hydroxy-cis-myristol-7-eoyl-[acyl-carrier protein]',
#  'Palmitoyl-ACP (n-C16:0ACP)',
#  'Cis-hexadec-9-enoyl-[acyl-carrier protein] (n-C16:1)',
#  'Acetyl phosphate',
#  'Trans-3-cis-7-myristoleoyl-[acyl-carrier protein]',
#  'Acetate',
#  '(S)-2-Acetolactate',
#  'Butyryl-ACP (n-C4:0ACP)',
#  'Trans-Hexadec-2-enoyl-[acyl-carrier protein]',
#  'Hexanoyl-ACP (n-C6:0ACP)',
#  '3-Oxoadipyl-CoA',
#  'D-Lactate',
#  'R-3-hydroxypalmitoyl-[acyl-carrier protein]',
#  'N-acetylmuramate 6-phosphate',
#  'L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate',
#  'Adenosine',
#  'L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate',
#  'Ammonium',
#  '4-Aminobenzoate',
#  'Dopamine',
#  'UDP C9H11N2O12P2',
#  '4-amino-4-deoxychorismate',
#  'O2 O2',
#  'UDP-N-acetyl-D-mannosaminouronate',
#  'Hypoxanthine',
#  'N-Acetyl-D-mannosamine 6-phosphate',
#  'Hydrogen peroxide',
#  '4-Hydroxyphenylacetaldehyde',
#  'Adenine',
#  '4-Hydroxy-L-threonine',
#  'N-Acetyl-D-mannosamine',
#  'GDP C10H12N5O11P2',
#  'N-Acetylmuramate',
#  'O-Phospho-4-hydroxy-L-threonine',
#  'ITP C10H11N4O14P3',
#  'D-Alanine',
#  'N-Acetylneuraminate',
#  'N-Acetylneuraminate',
#  'IDP C10H11N4O11P2',
#  'N-Acetyl-D-mannosamine',
#  'L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine',
#  'S-Adenosylmethioninamine',
#  'D-Alanine',
#  'Crotonoyl-CoA',
#  'CAMP C10H11N5O6P',
#  'Flavin adenine dinucleotide reduced',
#  'L-alanine-D-glutamate-meso-2,6-diaminoheptanedioate-D-alanine',
#  'D-Ribose',
#  '5-Dehydro-D-gluconate',
#  '5-Dehydro-D-gluconate',
#  'Trans-Hex-2-enoyl-CoA',
#  'Adenosyl cobinamide',
#  'Trans-Oct-2-enoyl-CoA',
#  'Trans-Dec-2-enoyl-CoA',
#  'Adenine',
#  'GMP C10H12N5O8P',
#  "5'-Deoxyadenosine",
#  'Trans-Dodec-2-enoyl-CoA',
#  'N1-(alpha-D-ribosyl)-5,6-dimethylbenzimidazole',
#  'Trans-Tetradec-2-enoyl-CoA',
#  '5-Methylthio-D-ribose',
#  'Adenosylcobalamin',
#  '5-Methylthio-D-ribose',
#  'Trans-Hexadec-2-enoyl-CoA',
#  'ADPribose C15H21N5O14P2',
#  'Trans-Octadec-2-enoyl-CoA',
#  'D-Ribulose 5-phosphate',
#  'Alpha-D-Ribose 5-phosphate',
#  'D-Arabinose 5-phosphate',
#  'Stearoyl-CoA (n-C18:0CoA)',
#  '5-Phospho-alpha-D-ribose 1-diphosphate',
#  'Acetyl-ACP',
#  'Cis-octadec-11-enoyl-[acyl-carrier protein] (n-C18:1)',
#  "3'-Phosphoadenylyl sulfate",
#  'Octadecanoyl-ACP (n-C18:0ACP)',
#  'N2-Acetyl-L-ornithine',
#  'Ornithine',
#  "Adenosine 5'-phosphosulfate",
#  '4-Amino-4-deoxy-L-arabinose modified core oligosaccharide lipid A',
#  'Decanoate (n-C10:0)',
#  'N6-(1,2-Dicarboxyethyl)-AMP',
#  'Octanoate (n-C8:0)',
#  'Trans-Aconitate',
#  'Fumarate',
#  'Cis-Aconitate',
#  'Hydrogen peroxide',
#  'Aminoacetone',
#  'Methylglyoxal',
#  'E-3-carboxy-2-pentenedioate 6-methyl ester',
#  'S-Adenosyl-L-homocysteine',
#  '5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide',
#  'Citrate',
#  'Isocitrate',
#  'Undecaprenyl-diphospho N-acetylglucosamine-N-acetylmannosaminuronate-N-acetamido-4,6-dideoxy-D-galactose',
#  '(S)-2-[5-Amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxamido]succinate',
#  'DTDP-4-acetamido-4,6-dideoxy-D-galactose',
#  'DTDP C10H13N2O11P2',
#  'N-Acetyl-L-glutamate 5-semialdehyde',
#  'IMP C10H11N4O8P',
#  'Dodecanoly-phosphate (n-C12:0)',
#  'Undecaprenyl-diphospho-N-acetylglucosamine-N-acetylmannosaminuronate',
#  'D-Glucosamine 6-phosphate',
#  'Maltohexaose',
#  'Tetradecanoyl-phosphate (n-C14:0)',
#  'N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide',
#  'Tetradecanoyl-phosphate (n-C14:1)',
#  'Maltohexaose',
#  'N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid',
#  'Arbutin 6-phosphate',
#  'Hexadecanoyl-phosphate (n-C16:0)',
#  'D-Glucose 6-phosphate',
#  'N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramic acid',
#  'Hydroquinone',
#  'Hexadecanoyl-phosphate (n-C16:1)',
#  'Octadecanoyl-phosphate (n-C18:0)',
#  'N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tripeptide',
#  'Octadecanoyl-phosphate (n-C18:1)',
#  '4-Aminobutanoate',
#  '1,6-anhydrous-N-Acetylmuramyl-tripeptide',
#  'Succinic semialdehyde',
#  "Adenosine 3',5'-bisphosphate",
#  'N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide',
#  'Apoprotein [acyl carrier protein]',
#  'N-Acetyl-D-glucosamine(anhydrous)N-Acetylmuramyl-tetrapeptide',
#  'O-Acetyl-L-serine',
#  '1,6-anhydrous-N-Acetylmuramyl-tetrapeptide',
#  'O-Acetyl-L-serine',
#  'Maltotetraose',
#  '1,6-anhydrous-N-Acetylmuramate',
#  'D-Glucose',
#  'Maltotriose C18H32O16',
#  'Acetate',
#  'ADP-L-glycero-D-manno-heptose',
#  'Sodium',
#  'Maltopentaose',
#  'ADP-D-glycero-D-manno-heptose',
#  'Maltoheptaose',
#  'Sodium',
#  'Inosine',
#  'Agmatine',
#  '7,8-Diaminononanoate',
#  'Urea CH4N2O',
#  '8-Amino-7-oxononanoate',
#  'Agmatine',
#  'Formate',
#  '7-deaza-7-carboxyguanine',
#  '1-dodecanoyl-sn-glycerol 3-phosphate',
#  'Cadmium',
#  'Cys Gly C5H10N2O3S',
#  '1,2-didodecanoyl-sn-glycerol 3-phosphate',
#  'L-Prolinylglycine',
#  'Cadmium',
#  '1-tetradecanoyl-sn-glycerol 3-phosphate',
#  'CMP C9H12N3O8P',
#  'AMP C10H12N5O7P',
#  'N-(5-Phospho-D-ribosyl)anthranilate',
#  '1,2-ditetradecanoyl-sn-glycerol 3-phosphate',
#  'CDP-1,2-didodecanoylglycerol',
#  'CDP-1,2-ditetradecanoylglycerol',
#  '1,2-ditetradec-7-enoyl-sn-glycerol 3-phosphate',
#  'CDP-1,2-ditetradec-7-enoylglycerol',
#  'L-2-Amino-3-oxobutanoate',
#  '1-tetradec-7-enoyl-sn-glycerol 3-phosphate',
#  'Pimeloyl-[acyl-carrier protein]',
#  "P1,P4-Bis(5'-adenosyl) tetraphosphate",
#  'CDP-1,2-dihexadecanoylglycerol',
#  '1,2-dihexadecanoyl-sn-glycerol 3-phosphate',
#  'CDP-1,2-dihexadec-9-enoylglycerol',
#  "P1,P5-Bis(5'-adenosyl) pentaphosphate",
#  'CDP-1,2-dioctadecanoylglycerol',
#  '1-hexadecanoyl-sn-glycerol 3-phosphate',
#  'CDP-1,2-dioctadec-11-enoylglycerol',
#  '5-Methylthioadenosine',
#  '1-hexadec-9-enoyl-sn-glycerol 3-phosphate',
#  '7-aminomethyl-7-deazaguanine',
#  '1,2-dihexadec-9-enoyl-sn-glycerol 3-phosphate',
#  '6-carboxy-5,6,7,8-tetrahydropterin',
#  '1,5-Diaminopentane',
#  '1-octadecanoyl-sn-glycerol 3-phosphate',
#  'N-3-aminopropyl-1,5-diaminopentane',
#  "4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol",
#  '1,2-dioctadecanoyl-sn-glycerol 3-phosphate',
#  "2-phospho-4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol",
#  'Cyclopropane phosphatidylethanolamine (dihexadec-9,10-cyclo-anoyl, n-C16:0 cyclo)',
#  'Glycerol 3-phosphate',
#  '1-Aminopropan-2-ol',
#  "5-Amino-6-(5'-phosphoribosylamino)uracil",
#  '1-octadec-11-enoyl-sn-glycerol 3-phosphate',
#  "5-Amino-6-(5'-phosphoribitylamino)uracil",
#  'Cyclopropane phosphatidylglycerol (dihexadec-9,10-cyclo-anoyl, n-C16:0 cyclo)',
#  'Cyclopropane phosphatidylethanolamine (dioctadec-11,12-cyclo-anoyl, n-C18:0 cyclo)',
#  '1,2-dioctadec-11-enoyl-sn-glycerol 3-phosphate',
#  'Cyclopropane phosphatidylglycerol (dioctadec-11,12-cyclo-anoyl, n-C18:0 cyclo)',
#  'L-Arabinose',
#  'L-Ribulose',
#  'Silver',
#  'Aerobactin minus Fe3',
#  'Cys Gly C5H10N2O3S',
#  'Choline C5H14NO',
#  'S-Ribosyl-L-homocysteine',
#  'Choline C5H14NO',
#  'Aerobactin',
#  '5-Formamido-1-(5-phospho-D-ribosyl)imidazole-4-carboxamide',
#  'FMN C17H19N4O9P',
#  'Prephenate',
#  '5-phosphoribosyl-5-carboxyaminoimidazole',
#  '5-O-(1-Carboxyvinyl)-3-phosphoshikimate',
#  'Reduced FMN',
#  'Reduced riboflavin',
#  '5-amino-1-(5-phospho-D-ribosyl)imidazole',
#  'Aerobactin',
#  '4-Hydroxybenzoate',
#  '5-amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxylate',
#  "N,N'-diacetylchitobiose",
#  'Diacetylchitobiose-6-phosphate',
#  'Aerobactin minus Fe3',
#  '2-Oxoglutarate',
#  'Arbutin C12H16O7',
#  'Cis-3-(3-carboxyethenyl)-3,5-cyclohexadiene-1,2-diol',
#  'D-Alanyl-D-alanine',
#  'Trans-Cinnamate',
#  'L-Arabinose',
#  'D-Alanyl-D-alanine',
#  'L-Arginine',
#  'CO2 CO2',
#  'Citrate',
#  'L-alanine-D-glutamate',
#  'Succinate',
#  'Ornithine',
#  'L-alanine-L-glutamate',
#  'N(omega)-(L-Arginino)succinate',
#  'Cold adapted KDO(2)-lipid (A)',
#  "Pyridoxamine 5'-phosphate",
#  '1,2-didodecanoyl-sn-glycerol 3-phosphate',
#  'Phosphatidylglycerol (didodecanoyl, n-C12:0)',
#  'L-Citrulline',
#  'TRNA(Ala)',
#  'TRNA(Arg)',
#  'Cardiolipin (tetradodecanoyl, n-C12:0)',
#  'L-Alanyl-tRNA(Ala)',
#  '1,2-ditetradecanoyl-sn-glycerol 3-phosphate',
#  'L-Arginyl-tRNA(Arg)',
#  'L-Alanine',
#  '4-Phospho-L-aspartate',
#  'Phosphatidylglycerol (ditetradecanoyl, n-C14:0)',
#  'L-Aspartate 4-semialdehyde',
#  'Glycerol',
#  'L-ascorbate-6-phosphate',
#  'Cardiolipin (tetratetradecanoyl, n-C14:0)',
#  '1,2-ditetradec-7-enoyl-sn-glycerol 3-phosphate',
#  'D-Glyceraldehyde',
#  'Cardiolipin (tetratetradec-7-enoyl, n-C14:1)',
#  'L-Ascorbate',
#  'Ethanol',
#  'L-Asparagine',
#  'Phosphatidylglycerol (ditetradec-7-enoyl, n-C14:1)',
#  'Phenylacetaldehyde',
#  '1,2-dihexadecanoyl-sn-glycerol 3-phosphate',
#  'L-Aspartate',
#  'Phenylacetic acid',
#  'TRNA Asn  C10H17O10PR2',
#  '1,2-dihexadec-9-enoyl-sn-glycerol 3-phosphate',
#  'Propanal',
#  'Cardiolipin (tetraoctadecanoyl, n-C18:0)',
#  'Phosphatidylglycerol (dioctadecanoyl, n-C18:0)',
#  'L-Asparaginyl-tRNA(Asn)',
#  'Butanal C4H8O',
#  'Arsenite',
#  'Arsenite',
#  '1,2-dioctadecanoyl-sn-glycerol 3-phosphate',
#  'Butyrate (n-C4:0)',
#  '1,2-dioctadec-11-enoyl-sn-glycerol 3-phosphate',
#  'Beta-Alanine',
#  'D-Allose 6-phosphate',
#  'N-Carbamoyl-L-aspartate',
#  'Glycerol',
#  'D-Allose',
#  'Chloride',
#  'Carbamoyl phosphate',
#  'Cytosine',
#  'Allulose 6-phosphate',
#  'CMP C9H12N3O8P',
#  'Iminoaspartate',
#  'Ubiquinone-8',
#  'Menaquinone 8',
#  'Chloramphenicol',
#  'Allantoate',
#  'Co2+',
#  'Succinate',
#  '(-)-Ureidoglycolate',
#  'Oxaloacetate',
#  'Undecaprenyl phosphate',
#  'L-Aspartyl-tRNA(Asp)',
#  'Allantoin',
#  'TRNA(Asp)',
#  'Undecaprenyl diphosphate',
#  'Core oligosaccharide lipid A diphosphate',
#  'Allantoin',
#  'Core oligosaccharide lipid A',
#  'Arsenate',
#  'D-Fructose 6-phosphate',
#  'Oxidized glutathione',
#  'Core oligosaccharide lipid A',
#  'D-Allose',
#  'Coprogen unloaded (no Fe(III))',
#  'N2-Succinyl-L-arginine',
#  'Applipoprotein',
#  'L-Allo-threonine',
#  'Coprogen',
#  'Lipoprotein',
#  'Coprogen unloaded (no Fe(III))',
#  '1-(5-Phosphoribosyl)-ATP',
#  'Acetol cytosol',
#  'Beta-Alanine',
#  'Coprogen',
#  '2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxypropyl)dihydropteridine triphosphate',
#  'Betaine aldehyde',
#  '2-Dehydro-3-deoxy-D-gluconate',
#  'Glycine betaine',
#  'Cyclic pyranopterin monophosphate',
#  'D-Altronate',
#  'Coproporphyrinogen III',
#  'Bis-molybdenum cofactor',
#  'Maltose C12H22O11',
#  'Adenylated molybdopterin',
#  'Protoporphyrinogen IX',
#  'Thiocyanate',
#  'L-Carnitine',
#  'L-Carnitinyl-CoA',
#  'Gamma-butyrobetainyl-CoA',
#  'Molybdenum cofactor',
#  'Bis-molybdopterin mono-guanine dinucleotide',
#  'Biotin',
#  'Sulfite',
#  'Dethiobiotin',
#  'Gamma-butyrobetaine',
#  'Cyanate',
#  'D-carnitinyl-CoA',
#  '[2Fe-1S] desulfurated iron-sulfur cluster',
#  'Butanesulfonate',
#  'Cyanate',
#  'Butanesulfonate',
#  'Crotonobetaine',
#  'Crotonobetainyl-CoA',
#  'D-Cysteine',
#  'D-Carnitine',
#  'Butyrate (n-C4:0)',
#  'Hydrogen sulfide',
#  'Tungsten bispterin cofactor mono-guanine dinucleotide',
#  'D-Carnitine',
#  'D-Cysteine',
#  'L-Carnitine',
#  'Tungsten bispterin cofactor',
#  'Gamma-butyrobetaine',
#  'Sulfur dioxide',
#  'Uracil',
#  'Tungsten bispterin cofactor guanine dinucleotide',
#  'Tungsten binding cofactor',
#  '3-Sulfino-L-alanine',
#  'Calcium',
#  'Cytosine',
#  'L-Cystathionine',
#  'Crotonobetaine',
#  'L-Lysine',
#  ...]

# %%
import random
random.choice(model.getListOfSpecies())
# Out:
# <Species M_frdp_r "Farnesyl diphosphate">

# %%
total_chebis = []
total_rheas = []
total_specs = []
total_reacs = []

models = []
num_species = []
name_lengths = []
num_annotated_species = []
num_unique_chebis = []
num_reactions = []
num_components = []
num_annotated_reactions = []
num_unique_rheas = []


for idx, one_bigg in enumerate(biggs):
  if idx % 10 == 0:
    print("We're at", idx)
  one_fpath = os.path.join(BIGG_DIR, one_bigg)
  recom = recommender.Recommender(libsbml_fpath=one_fpath)
  models.append(one_bigg)
  num_species.append(len(recom.species.names))
  name_lengths.append(np.mean([len(recom.species.names[k]) \
                               for k in recom.species.names.keys()]))
  num_annotated_species.append(len(recom.species.exist_annotation))
  unique_chebis = list(set(itertools.chain(*[recom.species.exist_annotation[k] \
                  for k in recom.species.exist_annotation.keys()])))
  num_reactions.append(len(recom.reactions.reaction_components))
  num_components.append(np.mean([len(recom.reactions.reaction_components[k]) \
                           for k in recom.reactions.reaction_components.keys()]))
  num_annotated_reactions.append(len(recom.reactions.exist_annotation))
  unique_rheas = list(set(itertools.chain(*[recom.reactions.exist_annotation[k] \
                 for k in recom.reactions.exist_annotation.keys()])))
  num_unique_chebis.append(len(unique_chebis))
  num_unique_rheas.append(len(unique_rheas))
  total_specs.append(list(recom.species.names.keys()))
  total_reacs.append(list(recom.reactions.reaction_components.keys()))
  total_chebis.append(unique_chebis)
  total_rheas.append(unique_rheas)

bigg_summary = pd.DataFrame({'model': models,
                              'num_species': num_species,
                              'name_lengths': name_lengths,
                              'num_annotated_species': num_annotated_species,
                              'num_unique_chebis': num_unique_chebis,
                              'num_reactions': num_reactions, 
                              'num_components': num_components,
                              'num_annotated_reactions': num_annotated_reactions,
                              'num_unique_rheas': num_unique_rheas})
specs = list(set(itertools.chain(*total_specs)))
reacs = list(set(itertools.chain(*total_reacs)))
chebis = list(set(itertools.chain(*total_chebis)))
rheas = list(set(itertools.chain(*total_rheas)))
bigg_total = {'specs': specs, 'reacs': reacs,
              'chebis':chebis, 'rheas': rheas}

# %%
# check if any of them have kinetics, other than biomodels

# %%
# Kripendorff's alpha: checking  
#
