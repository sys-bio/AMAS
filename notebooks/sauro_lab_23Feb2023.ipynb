# %%
# Data for Sauro Lab presentation
import os
import matplotlib.pyplot as plt
import networkx as nx

# %%
PRESENTATION_DIR = '/Users/woosubs/Desktop/AutomateAnnotation/presentation/sauro_lab/feb23_2023'

# %%
g = nx.Graph()
# CHEBI:16449 (alanine)
# CHEBI:16708 (adenine)
# CHEBI:13193 (hydrogen acceptor)
g.add_edge("a", "'a'", weight=0.0)
g.add_edge("a", "CHEBI:16449", weight=1.0)
g.add_edge("a", "CHEBI:16708", weight=1.0)
g.add_edge("a", "CHEBI:13193", weight=1.0)
g.add_edge("alanine", "CHEBI:16449", weight=1.0)
g.add_edge("adenine", "CHEBI:16708", weight=1.0)
g.add_edge("hydrogen acceptor", "CHEBI:13193", weight=1.0)

# %%
#https://networkx.org/documentation/stable/auto_examples/drawing/plot_weighted_graph.html

elarge = [(u, v) for (u, v, d) in g.edges(data=True) if d["weight"] > 0.5]
esmall = [(u, v) for (u, v, d) in g.edges(data=True) if d["weight"] <= 0.5]
# nodes
pos = nx.spring_layout(g, seed=7)

color_map = []
for node in g:
    if node[:5]=='CHEBI':
        color_map.append('lightpink')
    else:
        color_map.append('skyblue')

nx.draw_networkx_nodes(g, pos, node_color=color_map, node_size=700)

# edges
nx.draw_networkx_edges(g, pos, edgelist=elarge, width=6)
nx.draw_networkx_edges(
    g, pos, edgelist=esmall, width=4, alpha=0.5, edge_color="b", style="dashed"
)

# node labels
nx.draw_networkx_labels(g, pos, font_size=12, font_family="sans-serif")
# edge weight labels
edge_labels = nx.get_edge_attributes(g, "weight")
nx.draw_networkx_edge_labels(g, pos, edge_labels)

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()


plt.savefig(os.path.join(PRESENTATION_DIR, "original_g.png"), format="PNG")
plt.show()

# %%
for node in g:
  print(node)
# Out:
# a
# CHEBI:16449
# CHEBI:16708
# CHEBI:13193
# alanine
# adenine
# hydrogen acceptor

# %%
g2 = nx.Graph()
# CHEBI:42758	1.0	aldehydo-D-glucose
# CHEBI:4167	1.0	D-glucopyranose
# CHEBI:17234	1.0	glucose
g2.add_edge("glucose", "CHEBI:42758", weight=1.0)
g2.add_edge("glucose", "CHEBI:4167", weight=1.0)
g2.add_edge("glucose", "CHEBI:17234", weight=1.0)
g2.add_edge("aldehydo-D-glucose", "CHEBI:42758", weight=1.0)
g2.add_edge("D-glucopyranose", "CHEBI:4167", weight=1.0)
g2.add_edge("glucose", "glucosC", weight=0.118)

elarge = [(u, v) for (u, v, d) in g2.edges(data=True) if d["weight"] > 0.5]
esmall = [(u, v) for (u, v, d) in g2.edges(data=True) if d["weight"] <= 0.5]
# nodes
pos = nx.spring_layout(g2, seed=7)

color_map = []
for node in g2:
    if node[:5]=='CHEBI':
        color_map.append('lightpink')
    else:
        color_map.append('skyblue')

nx.draw_networkx_nodes(g2, pos, node_color=color_map, node_size=700)

# edges
nx.draw_networkx_edges(g2, pos, edgelist=elarge, width=6)
nx.draw_networkx_edges(
    g2, pos, edgelist=esmall, width=4, alpha=0.5, edge_color="b", style="dashed"
)

# node labels
nx.draw_networkx_labels(g2, pos, font_size=8, font_family="sans-serif")
# edge weight labels
edge_labels = nx.get_edge_attributes(g2, "weight")
nx.draw_networkx_edge_labels(g2, pos, edge_labels)

ax = plt.gca()
ax.margins(0.05)
plt.axis("off")
plt.tight_layout(pad=0.5, w_pad=0.5, h_pad=0.5)

plt.savefig(os.path.join(PRESENTATION_DIR, "original_g2_glucosc.png"), format="PNG")
plt.show()

# %%
for node in g2:
  print(node)
# Out:
# glucose
# CHEBI:42758
# CHEBI:4167
# CHEBI:17234
# aldehydo-D-glucose
# D-glucopyranose
