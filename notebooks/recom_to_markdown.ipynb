# %%
# adding to_markdown option for recom.get...Annotation
import collections
import copy
import itertools
import libsbml
import numpy as np
import os
import pickle
import pandas as pd
import sys
import matplotlib.pyplot as plt
# %matplotlib inline  

BIOMD_12 = 'BIOMD0000000012.xml'
BASE_DIR = '/Users/woosubs/Desktop/AutomateAnnotation/'
DATA_DIR = os.path.join(BASE_DIR, "DATA")
ALGO_DIR = os.path.join(DATA_DIR, "algo")
CHEBI_DIR = os.path.join(DATA_DIR, "chebi")
RHEA_DIR = os.path.join(DATA_DIR, "rhea")
BIOMODEL_DIR = os.path.join(DATA_DIR, "biomodels/curated_biomodels_31mar2021")
BIGG_DIR = '/Users/woosubs/Desktop/AutomateAnnotation/DATA/bigg'
ecoli_fpath = os.path.join(BIGG_DIR, "e_coli_core.xml")

PROJ_DIR = os.path.join(os.getcwd(), os.pardir)
AMAS_DIR = os.path.join(PROJ_DIR, "AMAS")
sys.path.append(PROJ_DIR)

from AMAS import species_annotation as sa
from AMAS import reaction_annotation as ra
from AMAS import recommender
from AMAS import constants as cn
from AMAS import iterator as it
from AMAS import tools

# %%
reader = libsbml.SBMLReader()
document = reader.readSBML(ecoli_fpath)
model = document.getModel()
recom = recommender.Recommender(libsbml_fpath=ecoli_fpath)

# %%
RESULT_RECOM = cn.Recommendation('R_PFK', 0.801,
                                 [('RHEA:12423', 0.6), ('RHEA:13380', 0.6)],
                                 ['https://www.rhea-db.org/rhea/12423', 'https://www.rhea-db.org/rhea/13380'])
recom.getMarkdownFromRecommendation(inp_recom=RESULT_RECOM)
# Out:
# '                   R_PFK (credibility score: 0.801)                  \n+--------------+---------------+------------------------------------+\n| annotation   |   match_score | url                                |\n+==============+===============+====================================+\n| RHEA:12423   |         0.600 | https://www.rhea-db.org/rhea/12423 |\n+--------------+---------------+------------------------------------+\n| RHEA:13380   |         0.600 | https://www.rhea-db.org/rhea/13380 |\n+--------------+---------------+------------------------------------+'

# %%
one_reaction = 'R_PFK'
print(recom.reactions.reaction_components[one_reaction])
# Out:
# ['M_f6p_c', 'M_adp_c', 'M_atp_c', 'M_h_c', 'M_fdp_c']

# %%
recom = recommender.Recommender(libsbml_fpath=ecoli_fpath)
one_recom = recom.getReactionAnnotation(pred_id = one_reaction, spec_method='cdist')

# %%
one_markd = recom.getSpeciesAnnotation(pred_id='M_fdp_c', get_markdown=True)
print(one_markd)
# Out:
#                                M_fdp_c (credibility score: 0.975)
# +--------------+---------------+---------------------------------------------------------------+
# | annotation   |   match_score | url                                                           |
# +==============+===============+===============================================================+
# | CHEBI:49299  |         1.000 | https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI%3A49299 |
# +--------------+---------------+---------------------------------------------------------------+
# | CHEBI:16905  |         1.000 | https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI%3A16905 |
# +--------------+---------------+---------------------------------------------------------------+

# %%
two_marks = recom.getSpeciesListAnnotation(pred_ids=['M_fdp_c', 'M_atp_c'], get_markdown=True)
for one_m in two_marks:
  print(one_m)
# Out:
#                                M_fdp_c (credibility score: 0.975)
# +--------------+---------------+---------------------------------------------------------------+
# | annotation   |   match_score | url                                                           |
# +==============+===============+===============================================================+
# | CHEBI:49299  |         1.000 | https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI%3A49299 |
# +--------------+---------------+---------------------------------------------------------------+
# | CHEBI:16905  |         1.000 | https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI%3A16905 |
# +--------------+---------------+---------------------------------------------------------------+
#                                 M_atp_c (credibility score: 0.958)
# +--------------+---------------+----------------------------------------------------------------+
# | annotation   |   match_score | url                                                            |
# +==============+===============+================================================================+
# | CHEBI:153955 |         0.840 | https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI%3A153955 |
# +--------------+---------------+----------------------------------------------------------------+

# %%
three_markd = recom.getReactionAnnotation(pred_id='R_PFK', get_markdown=True)
print(three_markd)
# Out:
#                    R_PFK (credibility score: 0.801)
# +--------------+---------------+------------------------------------+
# | annotation   |   match_score | url                                |
# +==============+===============+====================================+
# | RHEA:12423   |         0.600 | https://www.rhea-db.org/rhea/12423 |
# +--------------+---------------+------------------------------------+
# | RHEA:13380   |         0.600 | https://www.rhea-db.org/rhea/13380 |
# +--------------+---------------+------------------------------------+
# | RHEA:13616   |         0.600 | https://www.rhea-db.org/rhea/13616 |
# +--------------+---------------+------------------------------------+
# | RHEA:14216   |         0.600 | https://www.rhea-db.org/rhea/14216 |
# +--------------+---------------+------------------------------------+
# | RHEA:15656   |         0.600 | https://www.rhea-db.org/rhea/15656 |
# +--------------+---------------+------------------------------------+
# | RHEA:16112   |         0.600 | https://www.rhea-db.org/rhea/16112 |
# +--------------+---------------+------------------------------------+
# | RHEA:16772   |         0.600 | https://www.rhea-db.org/rhea/16772 |
# +--------------+---------------+------------------------------------+
# | RHEA:20108   |         0.600 | https://www.rhea-db.org/rhea/20108 |
# +--------------+---------------+------------------------------------+
# | RHEA:20644   |         0.600 | https://www.rhea-db.org/rhea/20644 |
# +--------------+---------------+------------------------------------+
# | RHEA:33806   |         0.600 | https://www.rhea-db.org/rhea/33806 |
# +--------------+---------------+------------------------------------+

# %%
four_marks = recom.getReactionListAnnotation(pred_ids=['R_PFK', 'R_PFL'], get_markdown=True)
for one_m in four_marks:
  print(one_m)
# Out:
#                    R_PFK (credibility score: 0.801)
# +--------------+---------------+------------------------------------+
# | annotation   |   match_score | url                                |
# +==============+===============+====================================+
# | RHEA:12423   |         0.600 | https://www.rhea-db.org/rhea/12423 |
# +--------------+---------------+------------------------------------+
# | RHEA:13380   |         0.600 | https://www.rhea-db.org/rhea/13380 |
# +--------------+---------------+------------------------------------+
# | RHEA:13616   |         0.600 | https://www.rhea-db.org/rhea/13616 |
# +--------------+---------------+------------------------------------+
# | RHEA:14216   |         0.600 | https://www.rhea-db.org/rhea/14216 |
# +--------------+---------------+------------------------------------+
# | RHEA:15656   |         0.600 | https://www.rhea-db.org/rhea/15656 |
# +--------------+---------------+------------------------------------+
# | RHEA:16112   |         0.600 | https://www.rhea-db.org/rhea/16112 |
# +--------------+---------------+------------------------------------+
# | RHEA:16772   |         0.600 | https://www.rhea-db.org/rhea/16772 |
# +--------------+---------------+------------------------------------+
# | RHEA:20108   |         0.600 | https://www.rhea-db.org/rhea/20108 |
# +--------------+---------------+------------------------------------+
# | RHEA:20644   |         0.600 | https://www.rhea-db.org/rhea/20644 |
# +--------------+---------------+------------------------------------+
# | RHEA:33806   |         0.600 | https://www.rhea-db.org/rhea/33806 |
# +--------------+---------------+------------------------------------+
#                    R_PFL (credibility score: 0.920)
# +--------------+---------------+------------------------------------+
# | annotation   |   match_score | url                                |
# +==============+===============+====================================+
# | RHEA:11847   |         1.000 | https://www.rhea-db.org/rhea/11847 |
# +--------------+---------------+------------------------------------+
# | RHEA:17428   |         0.800 | https://www.rhea-db.org/rhea/17428 |
# +--------------+---------------+------------------------------------+
# | RHEA:22991   |         0.800 | https://www.rhea-db.org/rhea/22991 |
# +--------------+---------------+------------------------------------+
# | RHEA:22995   |         0.800 | https://www.rhea-db.org/rhea/22995 |
# +--------------+---------------+------------------------------------+
# | RHEA:28045   |         0.800 | https://www.rhea-db.org/rhea/28045 |
# +--------------+---------------+------------------------------------+
# | RHEA:12768   |         0.667 | https://www.rhea-db.org/rhea/12768 |
# +--------------+---------------+------------------------------------+
# | RHEA:21915   |         0.667 | https://www.rhea-db.org/rhea/21915 |
# +--------------+---------------+------------------------------------+
# | RHEA:44143   |         0.667 | https://www.rhea-db.org/rhea/44143 |
# +--------------+---------------+------------------------------------+

# %%
recom.reactions.exist_annotation
# Out:
# {'R_PFK': ['RHEA:16112'],
#  'R_PFL': ['RHEA:11847'],
#  'R_PGI': ['RHEA:11819'],
#  'R_PGK': ['RHEA:14804'],
#  'R_PGL': ['RHEA:12559'],
#  'R_ACALD': ['RHEA:23291'],
#  'R_AKGt2r': ['RHEA:29014'],
#  'R_PGM': ['RHEA:21907', 'RHEA:15904'],
#  'R_PIt2r': ['RHEA:29942'],
#  'R_ALCD2x': ['RHEA:10743', 'RHEA:25293', 'RHEA:10739', 'RHEA:15940'],
#  'R_ACKr': ['RHEA:23151', 'RHEA:11355'],
#  'R_PPC': ['RHEA:28373', 'RHEA:23075'],
#  'R_ACONTa': ['RHEA:10339', 'RHEA:10231'],
#  'R_ACONTb': ['RHEA:22147', 'RHEA:10339'],
#  'R_ATPM': ['RHEA:27765',
#   'RHEA:64915',
#   'RHEA:20855',
#   'RHEA:29402',
#   'RHEA:23683',
#   'RHEA:29398',
#   'RHEA:36798',
#   'RHEA:13068',
#   'RHEA:29394',
#   'RHEA:14248'],
#  'R_PPCK': ['RHEA:18620'],
#  'R_PPS': ['RHEA:11367'],
#  'R_ADK1': ['RHEA:12976'],
#  'R_AKGDH': ['RHEA:15216',
#   'RHEA:27789',
#   'RHEA:33062',
#   'RHEA:21403',
#   'RHEA:15048',
#   'RHEA:12191'],
#  'R_PTAr': ['RHEA:19524'],
#  'R_PYK': ['RHEA:30730',
#   'RHEA:30298',
#   'RHEA:56951',
#   'RHEA:56959',
#   'RHEA:18160',
#   'RHEA:56955'],
#  'R_RPE': ['RHEA:13680'],
#  'R_CS': ['RHEA:16848'],
#  'R_RPI': ['RHEA:14660'],
#  'R_SUCCt2_2': ['RHEA:29306'],
#  'R_ENO': ['RHEA:10167'],
#  'R_SUCDi': ['RHEA:29190'],
#  'R_SUCOAS': ['RHEA:17664'],
#  'R_TALA': ['RHEA:17056'],
#  'R_THD2': ['RHEA:11695'],
#  'R_TKT1': ['RHEA:27629', 'RHEA:10511'],
#  'R_TKT2': ['RHEA:27629', 'RHEA:10511'],
#  'R_TPI': ['RHEA:18588'],
#  'R_EX_ac_e': ['RHEA:27817'],
#  'R_EX_etoh_e': ['RHEA:35270'],
#  'R_EX_for_e': ['RHEA:29682'],
#  'R_EX_h_e': ['RHEA:34982'],
#  'R_EX_h2o_e': ['RHEA:29670'],
#  'R_EX_nh4_e': ['RHEA:28750'],
#  'R_EX_pi_e': ['RHEA:32826'],
#  'R_FBA': ['RHEA:14732'],
#  'R_FBP': ['RHEA:11067'],
#  'R_FORt': ['RHEA:29682'],
#  'R_FRD7': ['RHEA:29190'],
#  'R_FUM': ['RHEA:12463'],
#  'R_FUMt2_2': ['RHEA:29334'],
#  'R_G6PDH2r': ['RHEA:15844', 'RHEA:38218'],
#  'R_GAPD': ['RHEA:10299', 'RHEA:10303'],
#  'R_GLNS': ['RHEA:16172'],
#  'R_GLUDy': ['RHEA:15136', 'RHEA:11615', 'RHEA:15504'],
#  'R_GLUN': ['RHEA:15892',
#   'RHEA:21019',
#   'RHEA:31510',
#   'RHEA:18636',
#   'RHEA:26429',
#   'RHEA:15504',
#   'RHEA:12231',
#   'RHEA:12131',
#   'RHEA:11683'],
#  'R_GLUSy': ['RHEA:15504'],
#  'R_GND': ['RHEA:33026', 'RHEA:10119'],
#  'R_H2Ot': ['RHEA:29670'],
#  'R_ICDHyr': ['RHEA:19632'],
#  'R_ICL': ['RHEA:13248'],
#  'R_LDH_D': ['RHEA:16372'],
#  'R_MALS': ['RHEA:18184'],
#  'R_MALt2_2': ['RHEA:29342'],
#  'R_MDH': ['RHEA:21435', 'RHEA:10827'],
#  'R_ME1': ['RHEA:12656', 'RHEA:15644'],
#  'R_ME2': ['RHEA:18256', 'RHEA:15644'],
#  'R_NADTRHD': ['RHEA:11695'],
#  'R_NH4t': ['RHEA:28750'],
#  'R_PDH': ['RHEA:28045',
#   'RHEA:17020',
#   'RHEA:33154',
#   'RHEA:33062',
#   'RHEA:15048',
#   'RHEA:17428',
#   'RHEA:19192']}

# %%
one_recom
# Out:
# Recommendation(id='R_PFK', credibility=0.801, candidates=[('RHEA:12423', 0.6), ('RHEA:13380', 0.6), ('RHEA:13616', 0.6), ('RHEA:14216', 0.6), ('RHEA:15656', 0.6), ('RHEA:16112', 0.6), ('RHEA:16772', 0.6), ('RHEA:20108', 0.6), ('RHEA:20644', 0.6), ('RHEA:33806', 0.6)], urls=['https://www.rhea-db.org/rhea/12423', 'https://www.rhea-db.org/rhea/13380', 'https://www.rhea-db.org/rhea/13616', 'https://www.rhea-db.org/rhea/14216', 'https://www.rhea-db.org/rhea/15656', 'https://www.rhea-db.org/rhea/16112', 'https://www.rhea-db.org/rhea/16772', 'https://www.rhea-db.org/rhea/20108', 'https://www.rhea-db.org/rhea/20644', 'https://www.rhea-db.org/rhea/33806'])

# %%
def getMarkdownFromRecommendation(inp_recom):
  """
  Get a markdown string for 
  a single recommendation.
  
  Parameters
  ----------
  inp_recom: cn.Recommendation
  
  Returns
  -------
  :str
  """
  cands = [val[0] for val in inp_recom.candidates]
  match_scores = [val[1] for val in inp_recom.candidates]
  urls = inp_recom.urls
  df = pd.DataFrame({'annotation':cands, 'match_score':match_scores, 'url':urls})
  df_str = df.to_markdown(tablefmt="grid", floatfmt=".03f", index=False)
  df_str = " %s (credibility score: %.03f)\n" % (inp_recom.id,  inp_recom.credibility) + \
           df_str
  return df_str

# %%
inp_recom = one_recom
cands = [val[0] for val in inp_recom.candidates]
match_scores = [val[1] for val in inp_recom.candidates]
urls = inp_recom.urls
df = pd.DataFrame({'annotation':cands, 'match_score':match_scores, 'url':urls})
df_str = df.to_markdown(tablefmt="grid", floatfmt=".03f", index=False)
len_first_line = len(df_str.split('\n')[0])
header_line = "%s (credibility score: %.03f)" % (inp_recom.id,  inp_recom.credibility)
header_line = header_line.center(len_first_line)
df_str = header_line + '\n' + df_str
print(df_str)
# Out:
#                    R_PFK (credibility score: 0.801)
# +--------------+---------------+------------------------------------+
# | annotation   |   match_score | url                                |
# +==============+===============+====================================+
# | RHEA:12423   |         0.600 | https://www.rhea-db.org/rhea/12423 |
# +--------------+---------------+------------------------------------+
# | RHEA:13380   |         0.600 | https://www.rhea-db.org/rhea/13380 |
# +--------------+---------------+------------------------------------+
# | RHEA:13616   |         0.600 | https://www.rhea-db.org/rhea/13616 |
# +--------------+---------------+------------------------------------+
# | RHEA:14216   |         0.600 | https://www.rhea-db.org/rhea/14216 |
# +--------------+---------------+------------------------------------+
# | RHEA:15656   |         0.600 | https://www.rhea-db.org/rhea/15656 |
# +--------------+---------------+------------------------------------+
# | RHEA:16112   |         0.600 | https://www.rhea-db.org/rhea/16112 |
# +--------------+---------------+------------------------------------+
# | RHEA:16772   |         0.600 | https://www.rhea-db.org/rhea/16772 |
# +--------------+---------------+------------------------------------+
# | RHEA:20108   |         0.600 | https://www.rhea-db.org/rhea/20108 |
# +--------------+---------------+------------------------------------+
# | RHEA:20644   |         0.600 | https://www.rhea-db.org/rhea/20644 |
# +--------------+---------------+------------------------------------+
# | RHEA:33806   |         0.600 | https://www.rhea-db.org/rhea/33806 |
# +--------------+---------------+------------------------------------+

# %%
RESULT_RECOM = cn.Recommendation('R_PFK', 0.801,
                                 [('RHEA:12423', 0.6), ('RHEA:13380', 0.6)],
                                 ['https://www.rhea-db.org/rhea/12423', 'https://www.rhea-db.org/rhea/13380'])

# %%
res = getMarkdownFromRecommendation(RESULT_RECOM)
print(res)
# Out:
#  R_PFK (credibility score: 0.801)
# +--------------+---------------+------------------------------------+
# | annotation   |   match_score | url                                |
# +==============+===============+====================================+
# | RHEA:12423   |         0.600 | https://www.rhea-db.org/rhea/12423 |
# +--------------+---------------+------------------------------------+
# | RHEA:13380   |         0.600 | https://www.rhea-db.org/rhea/13380 |
# +--------------+---------------+------------------------------------+

# %%
recom.species.exist_annotation
# Out:
# {'M_glc__D_e': ['CHEBI:12965', 'CHEBI:20999', 'CHEBI:4167', 'CHEBI:17634'],
#  'M_gln__L_c': ['CHEBI:42943',
#   'CHEBI:42899',
#   'CHEBI:32679',
#   'CHEBI:32678',
#   'CHEBI:58359',
#   'CHEBI:28300',
#   'CHEBI:42812',
#   'CHEBI:13110',
#   'CHEBI:18050',
#   'CHEBI:32666',
#   'CHEBI:6227',
#   'CHEBI:32665',
#   'CHEBI:21308',
#   'CHEBI:42814',
#   'CHEBI:5432',
#   'CHEBI:24316'],
#  'M_gln__L_e': ['CHEBI:42943',
#   'CHEBI:42899',
#   'CHEBI:32679',
#   'CHEBI:32678',
#   'CHEBI:58359',
#   'CHEBI:28300',
#   'CHEBI:42812',
#   'CHEBI:13110',
#   'CHEBI:18050',
#   'CHEBI:32666',
#   'CHEBI:6227',
#   'CHEBI:32665',
#   'CHEBI:21308',
#   'CHEBI:42814',
#   'CHEBI:5432',
#   'CHEBI:24316'],
#  'M_glu__L_c': ['CHEBI:76051',
#   'CHEBI:21301',
#   'CHEBI:29985',
#   'CHEBI:42825',
#   'CHEBI:29987',
#   'CHEBI:18237',
#   'CHEBI:24314',
#   'CHEBI:16015',
#   'CHEBI:13107',
#   'CHEBI:5431',
#   'CHEBI:21304',
#   'CHEBI:6224',
#   'CHEBI:14321',
#   'CHEBI:29988'],
#  'M_glu__L_e': ['CHEBI:76051',
#   'CHEBI:21301',
#   'CHEBI:29985',
#   'CHEBI:42825',
#   'CHEBI:29987',
#   'CHEBI:18237',
#   'CHEBI:24314',
#   'CHEBI:16015',
#   'CHEBI:13107',
#   'CHEBI:5431',
#   'CHEBI:21304',
#   'CHEBI:6224',
#   'CHEBI:14321',
#   'CHEBI:29988'],
#  'M_glx_c': ['CHEBI:24420',
#   'CHEBI:36655',
#   'CHEBI:14368',
#   'CHEBI:24421',
#   'CHEBI:42767',
#   'CHEBI:16891',
#   'CHEBI:35977',
#   'CHEBI:5509'],
#  'M_h2o_c': ['CHEBI:13352',
#   'CHEBI:30490',
#   'CHEBI:43228',
#   'CHEBI:33813',
#   'CHEBI:44292',
#   'CHEBI:44641',
#   'CHEBI:27313',
#   'CHEBI:42043',
#   'CHEBI:44819',
#   'CHEBI:29356',
#   'CHEBI:5594',
#   'CHEBI:10743',
#   'CHEBI:15377',
#   'CHEBI:42857',
#   'CHEBI:13365',
#   'CHEBI:29412',
#   'CHEBI:16234',
#   'CHEBI:13419',
#   'CHEBI:5585',
#   'CHEBI:44701'],
#  'M_h2o_e': ['CHEBI:13352',
#   'CHEBI:30490',
#   'CHEBI:43228',
#   'CHEBI:33813',
#   'CHEBI:44292',
#   'CHEBI:44641',
#   'CHEBI:27313',
#   'CHEBI:42043',
#   'CHEBI:44819',
#   'CHEBI:29356',
#   'CHEBI:5594',
#   'CHEBI:10743',
#   'CHEBI:15377',
#   'CHEBI:42857',
#   'CHEBI:13365',
#   'CHEBI:29412',
#   'CHEBI:16234',
#   'CHEBI:13419',
#   'CHEBI:5585',
#   'CHEBI:44701'],
#  'M_h_c': ['CHEBI:5584', 'CHEBI:13357', 'CHEBI:15378', 'CHEBI:10744'],
#  'M_h_e': ['CHEBI:5584', 'CHEBI:13357', 'CHEBI:15378', 'CHEBI:10744'],
#  'M_icit_c': ['CHEBI:16087',
#   'CHEBI:36454',
#   'CHEBI:5998',
#   'CHEBI:24886',
#   'CHEBI:36453',
#   'CHEBI:14465',
#   'CHEBI:30887',
#   'CHEBI:24884'],
#  'M_lac__D_c': ['CHEBI:16004',
#   'CHEBI:341',
#   'CHEBI:18684',
#   'CHEBI:43701',
#   'CHEBI:11001',
#   'CHEBI:42111',
#   'CHEBI:42105'],
#  'M_lac__D_e': ['CHEBI:16004',
#   'CHEBI:341',
#   'CHEBI:18684',
#   'CHEBI:43701',
#   'CHEBI:11001',
#   'CHEBI:42111',
#   'CHEBI:42105'],
#  'M_mal__L_c': ['CHEBI:15589',
#   'CHEBI:30797',
#   'CHEBI:423',
#   'CHEBI:18784',
#   'CHEBI:18785',
#   'CHEBI:13140',
#   'CHEBI:11066'],
#  'M_mal__L_e': ['CHEBI:15589',
#   'CHEBI:30797',
#   'CHEBI:423',
#   'CHEBI:18784',
#   'CHEBI:18785',
#   'CHEBI:13140',
#   'CHEBI:11066'],
#  'M_nad_c': ['CHEBI:7422',
#   'CHEBI:44215',
#   'CHEBI:13394',
#   'CHEBI:21901',
#   'CHEBI:57540',
#   'CHEBI:15846',
#   'CHEBI:44281',
#   'CHEBI:44214',
#   'CHEBI:13393',
#   'CHEBI:29867'],
#  'M_nadh_c': ['CHEBI:13395',
#   'CHEBI:21902',
#   'CHEBI:7423',
#   'CHEBI:44216',
#   'CHEBI:57945',
#   'CHEBI:16908',
#   'CHEBI:13396'],
#  'M_nadp_c': ['CHEBI:29868',
#   'CHEBI:44405',
#   'CHEBI:25523',
#   'CHEBI:13397',
#   'CHEBI:18009',
#   'CHEBI:7424',
#   'CHEBI:13398',
#   'CHEBI:21903',
#   'CHEBI:58349',
#   'CHEBI:44409'],
#  'M_nadph_c': ['CHEBI:16474',
#   'CHEBI:7425',
#   'CHEBI:57783',
#   'CHEBI:21904',
#   'CHEBI:13399',
#   'CHEBI:13400',
#   'CHEBI:44286'],
#  'M_nh4_c': ['CHEBI:44284',
#   'CHEBI:135980',
#   'CHEBI:22533',
#   'CHEBI:13406',
#   'CHEBI:29337',
#   'CHEBI:29340',
#   'CHEBI:13771',
#   'CHEBI:16134',
#   'CHEBI:28938',
#   'CHEBI:22534',
#   'CHEBI:13405',
#   'CHEBI:49783',
#   'CHEBI:7434',
#   'CHEBI:7435',
#   'CHEBI:44269',
#   'CHEBI:44404',
#   'CHEBI:13407'],
#  'M_13dpg_c': ['CHEBI:57604',
#   'CHEBI:20189',
#   'CHEBI:11881',
#   'CHEBI:16001',
#   'CHEBI:1658'],
#  'M_nh4_e': ['CHEBI:44284',
#   'CHEBI:135980',
#   'CHEBI:22533',
#   'CHEBI:13406',
#   'CHEBI:29337',
#   'CHEBI:29340',
#   'CHEBI:13771',
#   'CHEBI:16134',
#   'CHEBI:28938',
#   'CHEBI:22534',
#   'CHEBI:13405',
#   'CHEBI:49783',
#   'CHEBI:7434',
#   'CHEBI:7435',
#   'CHEBI:44269',
#   'CHEBI:44404',
#   'CHEBI:13407'],
#  'M_o2_c': ['CHEBI:7860',
#   'CHEBI:26689',
#   'CHEBI:29097',
#   'CHEBI:15379',
#   'CHEBI:13416',
#   'CHEBI:27140',
#   'CHEBI:29793',
#   'CHEBI:30491',
#   'CHEBI:44742',
#   'CHEBI:23833',
#   'CHEBI:25366',
#   'CHEBI:10745'],
#  'M_2pg_c': ['CHEBI:39868',
#   'CHEBI:21028',
#   'CHEBI:58289',
#   'CHEBI:24344',
#   'CHEBI:12986',
#   'CHEBI:17835',
#   'CHEBI:11651',
#   'CHEBI:1267',
#   'CHEBI:88350'],
#  'M_o2_e': ['CHEBI:7860',
#   'CHEBI:26689',
#   'CHEBI:29097',
#   'CHEBI:15379',
#   'CHEBI:13416',
#   'CHEBI:27140',
#   'CHEBI:29793',
#   'CHEBI:30491',
#   'CHEBI:44742',
#   'CHEBI:23833',
#   'CHEBI:25366',
#   'CHEBI:10745'],
#  'M_3pg_c': ['CHEBI:11879',
#   'CHEBI:11880',
#   'CHEBI:17794',
#   'CHEBI:21029',
#   'CHEBI:1657',
#   'CHEBI:58272',
#   'CHEBI:12987'],
#  'M_oaa_c': ['CHEBI:25731',
#   'CHEBI:24959',
#   'CHEBI:12820',
#   'CHEBI:16452',
#   'CHEBI:30744',
#   'CHEBI:14703',
#   'CHEBI:24958',
#   'CHEBI:7812',
#   'CHEBI:25734',
#   'CHEBI:29049'],
#  'M_pep_c': ['CHEBI:18021',
#   'CHEBI:44894',
#   'CHEBI:26054',
#   'CHEBI:14812',
#   'CHEBI:26055',
#   'CHEBI:8147',
#   'CHEBI:58702',
#   'CHEBI:44897'],
#  'M_6pgc_c': ['CHEBI:33851',
#   'CHEBI:2231',
#   'CHEBI:16863',
#   'CHEBI:40282',
#   'CHEBI:12232',
#   'CHEBI:48928',
#   'CHEBI:58759'],
#  'M_pi_c': ['CHEBI:26078',
#   'CHEBI:18367',
#   'CHEBI:29139',
#   'CHEBI:39739',
#   'CHEBI:43470',
#   'CHEBI:35780',
#   'CHEBI:43474',
#   'CHEBI:26020',
#   'CHEBI:45024',
#   'CHEBI:39745',
#   'CHEBI:29137',
#   'CHEBI:14791',
#   'CHEBI:7793'],
#  'M_6pgl_c': ['CHEBI:12233',
#   'CHEBI:4160',
#   'CHEBI:57955',
#   'CHEBI:16938',
#   'CHEBI:20989',
#   'CHEBI:12958'],
#  'M_pi_e': ['CHEBI:26078',
#   'CHEBI:18367',
#   'CHEBI:29139',
#   'CHEBI:39739',
#   'CHEBI:43470',
#   'CHEBI:35780',
#   'CHEBI:43474',
#   'CHEBI:26020',
#   'CHEBI:45024',
#   'CHEBI:39745',
#   'CHEBI:29137',
#   'CHEBI:14791',
#   'CHEBI:7793'],
#  'M_ac_c': ['CHEBI:13704',
#   'CHEBI:22165',
#   'CHEBI:22169',
#   'CHEBI:40480',
#   'CHEBI:15366',
#   'CHEBI:2387',
#   'CHEBI:30089',
#   'CHEBI:40486'],
#  'M_pyr_c': ['CHEBI:26462',
#   'CHEBI:26466',
#   'CHEBI:8685',
#   'CHEBI:32816',
#   'CHEBI:45253',
#   'CHEBI:14987',
#   'CHEBI:15361'],
#  'M_pyr_e': ['CHEBI:26462',
#   'CHEBI:26466',
#   'CHEBI:8685',
#   'CHEBI:32816',
#   'CHEBI:45253',
#   'CHEBI:14987',
#   'CHEBI:15361'],
#  'M_q8_c': ['CHEBI:61683'],
#  'M_q8h2_c': ['CHEBI:61682'],
#  'M_r5p_c': ['CHEBI:18189', 'CHEBI:22413', 'CHEBI:12331', 'CHEBI:10270'],
#  'M_ru5p__D_c': ['CHEBI:40192',
#   'CHEBI:21088',
#   'CHEBI:17363',
#   'CHEBI:26572',
#   'CHEBI:13040',
#   'CHEBI:37455',
#   'CHEBI:58121',
#   'CHEBI:13018',
#   'CHEBI:4243'],
#  'M_ac_e': ['CHEBI:13704',
#   'CHEBI:22165',
#   'CHEBI:22169',
#   'CHEBI:40480',
#   'CHEBI:15366',
#   'CHEBI:2387',
#   'CHEBI:30089',
#   'CHEBI:40486'],
#  'M_acald_c': ['CHEBI:40533',
#   'CHEBI:13703',
#   'CHEBI:2383',
#   'CHEBI:22158',
#   'CHEBI:15343'],
#  'M_s7p_c': ['CHEBI:4244',
#   'CHEBI:15073',
#   'CHEBI:15721',
#   'CHEBI:26621',
#   'CHEBI:9083',
#   'CHEBI:15074',
#   'CHEBI:57483'],
#  'M_acald_e': ['CHEBI:40533',
#   'CHEBI:13703',
#   'CHEBI:2383',
#   'CHEBI:22158',
#   'CHEBI:15343'],
#  'M_accoa_c': ['CHEBI:57288',
#   'CHEBI:22192',
#   'CHEBI:15351',
#   'CHEBI:13712',
#   'CHEBI:2408',
#   'CHEBI:40470'],
#  'M_succ_c': ['CHEBI:22941',
#   'CHEBI:26803',
#   'CHEBI:15741',
#   'CHEBI:132287',
#   'CHEBI:45639',
#   'CHEBI:30779',
#   'CHEBI:15125',
#   'CHEBI:22943',
#   'CHEBI:26807',
#   'CHEBI:9304',
#   'CHEBI:90372',
#   'CHEBI:30031'],
#  'M_succ_e': ['CHEBI:22941',
#   'CHEBI:26803',
#   'CHEBI:15741',
#   'CHEBI:132287',
#   'CHEBI:45639',
#   'CHEBI:30779',
#   'CHEBI:15125',
#   'CHEBI:22943',
#   'CHEBI:26807',
#   'CHEBI:9304',
#   'CHEBI:90372',
#   'CHEBI:30031'],
#  'M_succoa_c': ['CHEBI:57292',
#   'CHEBI:10746',
#   'CHEBI:15127',
#   'CHEBI:15380',
#   'CHEBI:9310',
#   'CHEBI:45541',
#   'CHEBI:26811'],
#  'M_acon_C_c': ['CHEBI:23306',
#   'CHEBI:16383',
#   'CHEBI:12798',
#   'CHEBI:32805',
#   'CHEBI:23308',
#   'CHEBI:10482'],
#  'M_xu5p__D_c': ['CHEBI:13036',
#   'CHEBI:27354',
#   'CHEBI:4269',
#   'CHEBI:16332',
#   'CHEBI:57737',
#   'CHEBI:21121'],
#  'M_actp_c': ['CHEBI:13711',
#   'CHEBI:46262',
#   'CHEBI:15350',
#   'CHEBI:22191',
#   'CHEBI:2407'],
#  'M_adp_c': ['CHEBI:2342',
#   'CHEBI:16761',
#   'CHEBI:456216',
#   'CHEBI:40553',
#   'CHEBI:22244',
#   'CHEBI:87518',
#   'CHEBI:13222'],
#  'M_akg_c': ['CHEBI:40661',
#   'CHEBI:16810',
#   'CHEBI:11638',
#   'CHEBI:30916',
#   'CHEBI:19749',
#   'CHEBI:1253',
#   'CHEBI:30915',
#   'CHEBI:19748'],
#  'M_akg_e': ['CHEBI:40661',
#   'CHEBI:16810',
#   'CHEBI:11638',
#   'CHEBI:30916',
#   'CHEBI:19749',
#   'CHEBI:1253',
#   'CHEBI:30915',
#   'CHEBI:19748'],
#  'M_amp_c': ['CHEBI:13736',
#   'CHEBI:2356',
#   'CHEBI:13234',
#   'CHEBI:22242',
#   'CHEBI:40786',
#   'CHEBI:16027',
#   'CHEBI:40721',
#   'CHEBI:40510',
#   'CHEBI:456215',
#   'CHEBI:13235',
#   'CHEBI:22245',
#   'CHEBI:40726',
#   'CHEBI:47222',
#   'CHEBI:13740',
#   'CHEBI:40826',
#   'CHEBI:12056'],
#  'M_atp_c': ['CHEBI:15422',
#   'CHEBI:10789',
#   'CHEBI:10841',
#   'CHEBI:2359',
#   'CHEBI:22249',
#   'CHEBI:13236',
#   'CHEBI:237958',
#   'CHEBI:30616',
#   'CHEBI:57299',
#   'CHEBI:40938'],
#  'M_cit_c': ['CHEBI:35802',
#   'CHEBI:133748',
#   'CHEBI:35809',
#   'CHEBI:76049',
#   'CHEBI:41523',
#   'CHEBI:35810',
#   'CHEBI:30769',
#   'CHEBI:13999',
#   'CHEBI:23322',
#   'CHEBI:35808',
#   'CHEBI:42563',
#   'CHEBI:16947',
#   'CHEBI:132362',
#   'CHEBI:35804',
#   'CHEBI:23321',
#   'CHEBI:3727',
#   'CHEBI:35806'],
#  'M_co2_c': ['CHEBI:23011',
#   'CHEBI:3283',
#   'CHEBI:48829',
#   'CHEBI:16526',
#   'CHEBI:13283',
#   'CHEBI:13285',
#   'CHEBI:13284',
#   'CHEBI:13282'],
#  'M_co2_e': ['CHEBI:23011',
#   'CHEBI:3283',
#   'CHEBI:48829',
#   'CHEBI:16526',
#   'CHEBI:13283',
#   'CHEBI:13285',
#   'CHEBI:13284',
#   'CHEBI:13282'],
#  'M_coa_c': ['CHEBI:41631',
#   'CHEBI:41597',
#   'CHEBI:741566',
#   'CHEBI:23355',
#   'CHEBI:13295',
#   'CHEBI:13298',
#   'CHEBI:57287',
#   'CHEBI:15346',
#   'CHEBI:3771',
#   'CHEBI:13294'],
#  'M_dhap_c': ['CHEBI:14341',
#   'CHEBI:5454',
#   'CHEBI:16108',
#   'CHEBI:14342',
#   'CHEBI:24355',
#   'CHEBI:39571',
#   'CHEBI:57642'],
#  'M_e4p_c': ['CHEBI:4114',
#   'CHEBI:20927',
#   'CHEBI:12921',
#   'CHEBI:48153',
#   'CHEBI:16897',
#   'CHEBI:42349'],
#  'M_etoh_c': ['CHEBI:42377',
#   'CHEBI:23978',
#   'CHEBI:30880',
#   'CHEBI:16236',
#   'CHEBI:52092',
#   'CHEBI:30878',
#   'CHEBI:4879',
#   'CHEBI:44594',
#   'CHEBI:14222'],
#  'M_etoh_e': ['CHEBI:42377',
#   'CHEBI:23978',
#   'CHEBI:30880',
#   'CHEBI:16236',
#   'CHEBI:52092',
#   'CHEBI:30878',
#   'CHEBI:4879',
#   'CHEBI:44594',
#   'CHEBI:14222'],
#  'M_f6p_c': ['CHEBI:16084',
#   'CHEBI:12352',
#   'CHEBI:57634',
#   'CHEBI:22768',
#   'CHEBI:10375',
#   'CHEBI:42378'],
#  'M_fdp_c': ['CHEBI:37736', 'CHEBI:49299'],
#  'M_for_c': ['CHEBI:24081',
#   'CHEBI:30751',
#   'CHEBI:15740',
#   'CHEBI:5145',
#   'CHEBI:42460',
#   'CHEBI:14276',
#   'CHEBI:24082'],
#  'M_for_e': ['CHEBI:24081',
#   'CHEBI:30751',
#   'CHEBI:15740',
#   'CHEBI:5145',
#   'CHEBI:42460',
#   'CHEBI:14276',
#   'CHEBI:24082'],
#  'M_fru_e': ['CHEBI:47424',
#   'CHEBI:28757',
#   'CHEBI:24110',
#   'CHEBI:20929',
#   'CHEBI:4119',
#   'CHEBI:15824',
#   'CHEBI:5172',
#   'CHEBI:24104',
#   'CHEBI:12923',
#   'CHEBI:4118',
#   'CHEBI:37714',
#   'CHEBI:37721',
#   'CHEBI:48095'],
#  'M_fum_c': ['CHEBI:36180',
#   'CHEBI:37155',
#   'CHEBI:42511',
#   'CHEBI:5190',
#   'CHEBI:18012',
#   'CHEBI:42743',
#   'CHEBI:22956',
#   'CHEBI:22957',
#   'CHEBI:24124',
#   'CHEBI:14284',
#   'CHEBI:37154',
#   'CHEBI:29806',
#   'CHEBI:22958',
#   'CHEBI:24122'],
#  'M_fum_e': ['CHEBI:36180',
#   'CHEBI:37155',
#   'CHEBI:42511',
#   'CHEBI:5190',
#   'CHEBI:18012',
#   'CHEBI:42743',
#   'CHEBI:22956',
#   'CHEBI:22957',
#   'CHEBI:24124',
#   'CHEBI:14284',
#   'CHEBI:37154',
#   'CHEBI:29806',
#   'CHEBI:22958',
#   'CHEBI:24122'],
#  'M_g3p_c': ['CHEBI:5446',
#   'CHEBI:14333',
#   'CHEBI:12984',
#   'CHEBI:181',
#   'CHEBI:17138',
#   'CHEBI:21026',
#   'CHEBI:12983',
#   'CHEBI:18324',
#   'CHEBI:58027',
#   'CHEBI:59776',
#   'CHEBI:29052'],
#  'M_g6p_c': ['CHEBI:61548', 'CHEBI:14314', 'CHEBI:4170']}

# %%
_ = recom.getSpeciesAnnotation('M_glc__D_e', get_m
# Out:
# ' R_PFK (credibility score: 0.801)\n+--------------+---------------+------------------------------------+\n| annotation   |   match_score | url                                |\n+==============+===============+====================================+\n| RHEA:12423   |         0.600 | https://www.rhea-db.org/rhea/12423 |\n+--------------+---------------+------------------------------------+\n| RHEA:13380   |         0.600 | https://www.rhea-db.org/rhea/13380 |\n+--------------+---------------+------------------------------------+'

# %%
rheas = [val[0] for val in one_recom.candidates]
match_scores = [('%.03f' % val[1]) for val in one_recom.candidates]
urls = one_recom.urls
df = pd.DataFrame({'rhea':rheas, 'match_score':match_scores, 'url':urls})
#df = df.style.set_caption("Recommendation for %s (Credibility Score: %.03f)" % (one_recom.id,  one_recom.credibility))

# %%
df_str = df.to_markdown(tablefmt="grid", index=False)
df_str = " %s (credibility score: %.03f)\n" % (one_recom.id,  one_recom.credibility) + \
         df_str
print(df_str)
# Out:
#  R_PFK (credibility score: 0.801)
# +------------+---------------+------------------------------------+
# | rhea       |   match_score | url                                |
# +============+===============+====================================+
# | RHEA:12423 |           0.6 | https://www.rhea-db.org/rhea/12423 |
# +------------+---------------+------------------------------------+
# | RHEA:13380 |           0.6 | https://www.rhea-db.org/rhea/13380 |
# +------------+---------------+------------------------------------+
# | RHEA:13616 |           0.6 | https://www.rhea-db.org/rhea/13616 |
# +------------+---------------+------------------------------------+
# | RHEA:14216 |           0.6 | https://www.rhea-db.org/rhea/14216 |
# +------------+---------------+------------------------------------+
# | RHEA:15656 |           0.6 | https://www.rhea-db.org/rhea/15656 |
# +------------+---------------+------------------------------------+
# | RHEA:16112 |           0.6 | https://www.rhea-db.org/rhea/16112 |
# +------------+---------------+------------------------------------+
# | RHEA:16772 |           0.6 | https://www.rhea-db.org/rhea/16772 |
# +------------+---------------+------------------------------------+
# | RHEA:20108 |           0.6 | https://www.rhea-db.org/rhea/20108 |
# +------------+---------------+------------------------------------+
# | RHEA:20644 |           0.6 | https://www.rhea-db.org/rhea/20644 |
# +------------+---------------+------------------------------------+
# | RHEA:33806 |           0.6 | https://www.rhea-db.org/rhea/33806 |
# +------------+---------------+------------------------------------+

# %%
one_recom.candidates
# Out:
# [('RHEA:12423', 0.6),
#  ('RHEA:13380', 0.6),
#  ('RHEA:13616', 0.6),
#  ('RHEA:14216', 0.6),
#  ('RHEA:15656', 0.6),
#  ('RHEA:16112', 0.6),
#  ('RHEA:16772', 0.6),
#  ('RHEA:20108', 0.6),
#  ('RHEA:20644', 0.6),
#  ('RHEA:33806', 0.6)]
